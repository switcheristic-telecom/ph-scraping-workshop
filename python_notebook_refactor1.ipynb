# %% [markdown]
# # Case study notebook
# The notebook features executable code snippets in the lesson.

# %%
# Downloading CDX data for each URL

import tenacity

retry = tenacity.retry(
    stop=tenacity.stop_after_attempt(10),
    wait=tenacity.wait_exponential(multiplier=1, min=2, max=32),
    after=lambda _: time.sleep(2),
)
import time
import requests

@retry
def download_cdx_data(url):
    time.sleep(1.5) # Observing the CDX Server rate limit as stipulated in the Github post cited above. 
    cdx_url = f"https://web.archive.org/cdx/search/cdx?url={url}&from=20000401000000&to=20000630235959&filter=statuscode:200&collapse=digest"
    print(f"Fetching CDX data for: {url}")
    response = requests.get(cdx_url, timeout=10)
    response.raise_for_status()

    if response.status_code == 200:
        return response.text
    else:
        raise Exception(f"Failed to fetch CDX data for {url}: {response.status_code}")

# %%
import csv
import hashlib
from pathlib import Path

csv_file = "nikkeibp-may2000-abridged.csv"

urls_data = []

# Load CSV file into dictionary
with open(csv_file, mode='r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    urls_data = list(reader)

# Generate a MD5 hash for each URL. 
# We will use this hash for saving the CDX data and HTML data. 

for url in urls_data:
    url['md5'] = hashlib.md5(url['url'].encode('utf-8')).hexdigest()

print(urls_data)

# Expected output: 
# [{'rank': '1', 'url': 'yahoo.co.jp', 'md5': 'e5fd6205dda399e39d9c3b055734f83f'}, ...
# Out:
# [{'rank': '1', 'url': 'yahoo.co.jp', 'md5': 'e5fd6205dda399e39d9c3b055734f83f'}, {'rank': '3', 'url': 'biglobe.ne.jp', 'md5': '598ca1bee5d257ac6f3c8477a61c14a2'}, {'rank': '4', 'url': 'geocities.co.jp', 'md5': '03e55e791b0c30a0e70b7fcb73d01894'}, {'rank': '5', 'url': 'nifty.com', 'md5': '02efb45e70adeb94cccd008670559250'}, {'rank': '6', 'url': 'nifty.ne.jp', 'md5': '245505630037d8a520036ff590e3cd2e'}, {'rank': '7', 'url': 'dti.ne.jp', 'md5': '5d5f85669bd24bde374e4e2da080b205'}, {'rank': '8', 'url': 'so-net.ne.jp', 'md5': '535bc4bb48fda288effb74883d8ab222'}, {'rank': '10', 'url': 'hi-ho.ne.jp', 'md5': 'bef081a841799df11166f1d69851d534'}, {'rank': '11', 'url': 'infoweb.ne.jp', 'md5': 'b53ae61a77ead6d7949a01a8b562d704'}, {'rank': '12', 'url': 'mbn.or.jp', 'md5': '4c46800776c8bb778889fda89a6a6b90'}, {'rank': '13', 'url': 'lycos.co.jp', 'md5': '425b80310c0dcf16ac09e4c76a273734'}, {'rank': '14', 'url': 'goo.ne.jp', 'md5': '9cec14420da076836a3fdc6e832b9b92'}, {'rank': '15', 'url': 'odn.ne.jp', 'md5': '893d39529188742980cc3522ae2b7df9'}, {'rank': '16', 'url': 'asahi-net.or.jp', 'md5': 'e51f896069b124422722693994038696'}, {'rank': '17', 'url': 'justnet.ne.jp', 'md5': '94376871a447d09d0041a67dfcad87ec'}, {'rank': '18', 'url': 'rim.or.jp', 'md5': '739c420c8f8ff54eba85bdc8dbd297aa'}, {'rank': '19', 'url': 'interq.or.jp', 'md5': 'f70109946396516168d10e7fc90cf456'}, {'rank': '20', 'url': 'iij4u.or.jp', 'md5': 'b5ad3c7900e51a0eb8c470eccbc6545e'}, {'rank': '21', 'url': 'neweb.ne.jp', 'md5': 'db84cb0d40b9f169a4643ee20c022d40'}, {'rank': '22', 'url': 'infoseek.co.jp', 'md5': 'c41512dcac09e2329ebc5c17564e4f6a'}, {'rank': '23', 'url': 'bekkoame.ne.jp', 'md5': '92932c1e54d99e8c6fac376add3ff8b2'}, {'rank': '24', 'url': 'ocn.ne.jp', 'md5': '2f856f8fd94db69056ec0c40d9723ff5'}, {'rank': '25', 'url': 'rakuten.co.jp', 'md5': '830ddf4e59a7f3c5ada3465445c8b9fa'}, {'rank': '26', 'url': 'dion.ne.jp', 'md5': '6528431ca292d1a40da7085469c250a2'}, {'rank': '27', 'url': 'plala.or.jp', 'md5': 'b3bdcb712d38128626fbb0c76fefed0f'}, {'rank': '28', 'url': 'freeweb.ne.jp', 'md5': 'd91d0c585020a45454ea2f383d3632b2'}, {'rank': '29', 'url': 'impress.co.jp', 'md5': '13e5183cb90bf76e7b92cbe7b2f6980d'}, {'rank': '30', 'url': 'nikkeibp.co.jp', 'md5': '8114c30ebe6c67f874c6bc24c94aaeb7'}, {'rank': '31', 'url': 'sakura.ne.jp', 'md5': '0a244c72332fad89ea19d23938d61f41'}, {'rank': '32', 'url': 'highway.ne.jp', 'md5': '58e98dfc94996a1d7f97f79d7f6ba9ed'}, {'rank': '33', 'url': 'tcup.com', 'md5': 'd4bffe3267a972738ae687eb26cf43d8'}, {'rank': '34', 'url': 'msn.co.jp', 'md5': 'a07316697496dfcb1e4e1dd41e3abec6'}, {'rank': '35', 'url': 'vector.co.jp', 'md5': 'a65a310ffdf9e798db8143f21de138ef'}, {'rank': '36', 'url': 'tripod.co.jp', 'md5': '8fe3236993fff804b28195320880f277'}, {'rank': '37', 'url': '3web.ne.jp', 'md5': '19d85e44f084d4b4d09373bfba3f576c'}, {'rank': '38', 'url': 'big.or.jp', 'md5': 'ecbaa42bb2fc11fb9bcdb25dc35e0147'}, {'rank': '39', 'url': 'cplaza.ne.jp', 'md5': 'dafd5d5b886aad6e89f76c2135329b73'}, {'rank': '40', 'url': 'iijnet.or.jp', 'md5': '44da265701c915e168eafe0248abb9fa'}, {'rank': '41', 'url': 'isize.com', 'md5': 'a26aface8846a624b68d7441323ad6ea'}, {'rank': '42', 'url': 'excite.co.jp', 'md5': 'e528d0efed0c242afcecb4e6ab1dab65'}, {'rank': '43', 'url': 'cool.ne.jp', 'md5': '2b0c7d6d57de273795c2fce2e398fdac'}, {'rank': '45', 'url': 'din.or.jp', 'md5': 'b4e722d81eee74c8eeb6c9986698619b'}, {'rank': '47', 'url': 'www.ne.jp', 'md5': '9dc00b08361ebb7d937f428bbc6d4fe1'}, {'rank': '48', 'url': 'xaxon.ne.jp', 'md5': '744cf7747fa551bada76b7650c8cfbbb'}, {'rank': '49', 'url': 'nikkei.co.jp', 'md5': '3e907a24a0769b56fc27880bc2db17be'}, {'rank': '50', 'url': 'asahi.com', 'md5': '439868a9c18529515a0be3529bfb20aa'}]

# %%
# This section downloads the CDX data for each URL in the dataset.
# It checks if the CDX data for the URL has already been downloaded, 
# and if not, it fetches the data from the Internet Archive's CDX API.

for url in urls_data: 
    # If the CDX data for the URL has already been downloaded, skip it.
    cdx_file_path = Path(f"data/{url['md5']}/cdx.csv")
    if cdx_file_path.exists():
        print(f"CDX data for {url['url']} already exists at {cdx_file_path}. Skipping download.")
        continue
    try:
        cdx_data = download_cdx_data(url['url'])
        # Save the CDX data to a file named after the MD5 hash of the URL
        cdx_file_path.parent.mkdir(parents=True, exist_ok=True)
        with open(cdx_file_path, 'w', encoding='utf-8') as cdx_file:
            cdx_file.write(cdx_data)
        print(f"CDX data saved for {url['url']} at {cdx_file_path}")
    except Exception as e:
        print(f"Error fetching CDX data for {url['url']}: {e}")
# Out:
# CDX data for yahoo.co.jp already exists at data/e5fd6205dda399e39d9c3b055734f83f/cdx.csv. Skipping download.
# CDX data for biglobe.ne.jp already exists at data/598ca1bee5d257ac6f3c8477a61c14a2/cdx.csv. Skipping download.
# CDX data for geocities.co.jp already exists at data/03e55e791b0c30a0e70b7fcb73d01894/cdx.csv. Skipping download.
# CDX data for nifty.com already exists at data/02efb45e70adeb94cccd008670559250/cdx.csv. Skipping download.
# CDX data for nifty.ne.jp already exists at data/245505630037d8a520036ff590e3cd2e/cdx.csv. Skipping download.
# CDX data for dti.ne.jp already exists at data/5d5f85669bd24bde374e4e2da080b205/cdx.csv. Skipping download.
# CDX data for so-net.ne.jp already exists at data/535bc4bb48fda288effb74883d8ab222/cdx.csv. Skipping download.
# CDX data for hi-ho.ne.jp already exists at data/bef081a841799df11166f1d69851d534/cdx.csv. Skipping download.
# CDX data for infoweb.ne.jp already exists at data/b53ae61a77ead6d7949a01a8b562d704/cdx.csv. Skipping download.
# CDX data for mbn.or.jp already exists at data/4c46800776c8bb778889fda89a6a6b90/cdx.csv. Skipping download.
# CDX data for lycos.co.jp already exists at data/425b80310c0dcf16ac09e4c76a273734/cdx.csv. Skipping download.
# CDX data for goo.ne.jp already exists at data/9cec14420da076836a3fdc6e832b9b92/cdx.csv. Skipping download.
# CDX data for odn.ne.jp already exists at data/893d39529188742980cc3522ae2b7df9/cdx.csv. Skipping download.
# CDX data for asahi-net.or.jp already exists at data/e51f896069b124422722693994038696/cdx.csv. Skipping download.
# CDX data for justnet.ne.jp already exists at data/94376871a447d09d0041a67dfcad87ec/cdx.csv. Skipping download.
# CDX data for rim.or.jp already exists at data/739c420c8f8ff54eba85bdc8dbd297aa/cdx.csv. Skipping download.
# CDX data for interq.or.jp already exists at data/f70109946396516168d10e7fc90cf456/cdx.csv. Skipping download.
# CDX data for iij4u.or.jp already exists at data/b5ad3c7900e51a0eb8c470eccbc6545e/cdx.csv. Skipping download.
# CDX data for neweb.ne.jp already exists at data/db84cb0d40b9f169a4643ee20c022d40/cdx.csv. Skipping download.
# CDX data for infoseek.co.jp already exists at data/c41512dcac09e2329ebc5c17564e4f6a/cdx.csv. Skipping download.
# CDX data for bekkoame.ne.jp already exists at data/92932c1e54d99e8c6fac376add3ff8b2/cdx.csv. Skipping download.
# CDX data for ocn.ne.jp already exists at data/2f856f8fd94db69056ec0c40d9723ff5/cdx.csv. Skipping download.
# CDX data for rakuten.co.jp already exists at data/830ddf4e59a7f3c5ada3465445c8b9fa/cdx.csv. Skipping download.
# CDX data for dion.ne.jp already exists at data/6528431ca292d1a40da7085469c250a2/cdx.csv. Skipping download.
# CDX data for plala.or.jp already exists at data/b3bdcb712d38128626fbb0c76fefed0f/cdx.csv. Skipping download.
# CDX data for freeweb.ne.jp already exists at data/d91d0c585020a45454ea2f383d3632b2/cdx.csv. Skipping download.
# CDX data for impress.co.jp already exists at data/13e5183cb90bf76e7b92cbe7b2f6980d/cdx.csv. Skipping download.
# CDX data for nikkeibp.co.jp already exists at data/8114c30ebe6c67f874c6bc24c94aaeb7/cdx.csv. Skipping download.
# CDX data for sakura.ne.jp already exists at data/0a244c72332fad89ea19d23938d61f41/cdx.csv. Skipping download.
# CDX data for highway.ne.jp already exists at data/58e98dfc94996a1d7f97f79d7f6ba9ed/cdx.csv. Skipping download.
# CDX data for tcup.com already exists at data/d4bffe3267a972738ae687eb26cf43d8/cdx.csv. Skipping download.
# CDX data for msn.co.jp already exists at data/a07316697496dfcb1e4e1dd41e3abec6/cdx.csv. Skipping download.
# CDX data for vector.co.jp already exists at data/a65a310ffdf9e798db8143f21de138ef/cdx.csv. Skipping download.
# CDX data for tripod.co.jp already exists at data/8fe3236993fff804b28195320880f277/cdx.csv. Skipping download.
# CDX data for 3web.ne.jp already exists at data/19d85e44f084d4b4d09373bfba3f576c/cdx.csv. Skipping download.
# CDX data for big.or.jp already exists at data/ecbaa42bb2fc11fb9bcdb25dc35e0147/cdx.csv. Skipping download.
# CDX data for cplaza.ne.jp already exists at data/dafd5d5b886aad6e89f76c2135329b73/cdx.csv. Skipping download.
# CDX data for iijnet.or.jp already exists at data/44da265701c915e168eafe0248abb9fa/cdx.csv. Skipping download.
# CDX data for isize.com already exists at data/a26aface8846a624b68d7441323ad6ea/cdx.csv. Skipping download.
# CDX data for excite.co.jp already exists at data/e528d0efed0c242afcecb4e6ab1dab65/cdx.csv. Skipping download.
# CDX data for cool.ne.jp already exists at data/2b0c7d6d57de273795c2fce2e398fdac/cdx.csv. Skipping download.
# CDX data for din.or.jp already exists at data/b4e722d81eee74c8eeb6c9986698619b/cdx.csv. Skipping download.
# CDX data for www.ne.jp already exists at data/9dc00b08361ebb7d937f428bbc6d4fe1/cdx.csv. Skipping download.
# CDX data for xaxon.ne.jp already exists at data/744cf7747fa551bada76b7650c8cfbbb/cdx.csv. Skipping download.
# CDX data for nikkei.co.jp already exists at data/3e907a24a0769b56fc27880bc2db17be/cdx.csv. Skipping download.
# CDX data for asahi.com already exists at data/439868a9c18529515a0be3529bfb20aa/cdx.csv. Skipping download.

# %%
# Analyze each CDX file and choose random snapshots for each URL 
# (if there is only one available snapshot to choose from, choose that one). 
# Make sure that the two snapshots have different digests. 

import random
def choose_random_snapshots_to_download(cdx_file_path, num_snapshots=2):

    print(f"Choosing {num_snapshots} random snapshots from {cdx_file_path}")

    # check if there are already any downloaded snapshots
    snapshots_dir = Path(cdx_file_path).parent
    downloaded_htmls = snapshots_dir.glob('*.html')
    # get file names without the extension
    downloaded_htmls = [html_file.stem for html_file in downloaded_htmls]
    print(f"Already downloaded {len(downloaded_htmls)} snapshots for {cdx_file_path}")
    num_snapshots -= len(downloaded_htmls)
    print(f"Number of new snapshots to download: {num_snapshots}")

    if num_snapshots <= 0:
        print(f"No new snapshots to download for {cdx_file_path}. Already have {len(downloaded_htmls)} downloaded.")
        return []
    
    # Read the CDX file and collect snapshots
    snapshots = []
    with open(cdx_file_path, 'r', encoding='utf-8') as cdx_file:
        reader = csv.reader(cdx_file, delimiter=' ')
        for row in reader:
            if len(row) >= 3:  # Ensure there are enough columns
                snapshots.append(row)
    
    # Remove duplicates based on the digest (6th column)
    unique_snapshots = {snapshot[5]: snapshot for snapshot in snapshots}.values()

    # Remove snapshots that have already been downloaded
    unique_snapshots = [snapshot for snapshot in unique_snapshots if snapshot[1] not in downloaded_htmls]
    
    # Randomly select the target number of snapshots
    selected_snapshots = random.sample(list(unique_snapshots), min(num_snapshots, len(unique_snapshots)))
    return selected_snapshots

print(choose_random_snapshots_to_download('data/d91d0c585020a45454ea2f383d3632b2/cdx.csv'))
# Out:
# Choosing 2 random snapshots from data/d91d0c585020a45454ea2f383d3632b2/cdx.csv
# Already downloaded 0 snapshots for data/d91d0c585020a45454ea2f383d3632b2/cdx.csv
# Number of new snapshots to download: 2
# [['jp,ne,freeweb)/', '20000519230330', 'http://www.freeweb.ne.jp:80/', 'text/html', '200', '3WQ75TY4LJIS2TOBCH27M5PHOQLMVIEX', '3527'], ['jp,ne,freeweb)/', '20000619102716', 'http://www10.freeweb.ne.jp:80/', 'text/html', '200', '7AV3CIHR7EVWQOENLZDE64PIGAIIGAZN', '878']]

# %%
# walk through all cdx files and download snapshots
@retry
def download_snapshot(url,timestamp):
    time.sleep(0.5)  # While this establishes a with lower request frequency than 480 per second, we want to be conservative here so avoid hitting the rate limit
    url = f"https://web.archive.org/web/{timestamp}id_/{url}"
    response = requests.get(url)
    response.encoding = response.apparent_encoding  
    return response.text 

# Download snapshots for each URL by iterating through the downloaded CDX files
cdx_files = Path("data").glob("*/cdx.csv")
for cdx_file in cdx_files:
    print(f"Processing CDX file: {cdx_file}")
    snapshots = choose_random_snapshots_to_download(cdx_file)
    
    for snapshot in snapshots:
        url, timestamp = snapshot[2], snapshot[1]
        print(f"Downloading snapshot for URL: {url} at timestamp: {timestamp}...")
        
        try:
            html_content = download_snapshot(url, timestamp)
            # Save the HTML content to a file named after the MD5 hash of the URL
            html_file_path = cdx_file.parent / f"{timestamp}.html"
            with open(html_file_path, 'w', encoding='utf-8') as html_file:
                html_file.write(html_content)
            print(f"Snapshot saved at {html_file_path}")
        except Exception as e:
            print(f"Error downloading snapshot for {url} at {timestamp}: {e}")
# Out:
# Processing CDX file: data/a65a310ffdf9e798db8143f21de138ef/cdx.csv
# Choosing 2 random snapshots from data/a65a310ffdf9e798db8143f21de138ef/cdx.csv
# Already downloaded 1 snapshots for data/a65a310ffdf9e798db8143f21de138ef/cdx.csv
# Number of new snapshots to download: 1
# Downloading snapshot for URL: http://www.vector.co.jp:80/? at timestamp: 20000520073937...
# Snapshot saved at data/a65a310ffdf9e798db8143f21de138ef/20000520073937.html
# Processing CDX file: data/425b80310c0dcf16ac09e4c76a273734/cdx.csv
# Choosing 2 random snapshots from data/425b80310c0dcf16ac09e4c76a273734/cdx.csv
# Already downloaded 1 snapshots for data/425b80310c0dcf16ac09e4c76a273734/cdx.csv
# Number of new snapshots to download: 1
# Downloading snapshot for URL: http://www.lycos.co.jp:80/ at timestamp: 20000510142936...
# Snapshot saved at data/425b80310c0dcf16ac09e4c76a273734/20000510142936.html
# Processing CDX file: data/5d5f85669bd24bde374e4e2da080b205/cdx.csv
# Choosing 2 random snapshots from data/5d5f85669bd24bde374e4e2da080b205/cdx.csv
# Already downloaded 0 snapshots for data/5d5f85669bd24bde374e4e2da080b205/cdx.csv
# Number of new snapshots to download: 2
# Processing CDX file: data/439868a9c18529515a0be3529bfb20aa/cdx.csv
# Choosing 2 random snapshots from data/439868a9c18529515a0be3529bfb20aa/cdx.csv
# Already downloaded 1 snapshots for data/439868a9c18529515a0be3529bfb20aa/cdx.csv
# Number of new snapshots to download: 1
# Downloading snapshot for URL: http://www.asahi.com:80/ at timestamp: 20000511072558...
# Snapshot saved at data/439868a9c18529515a0be3529bfb20aa/20000511072558.html
# Processing CDX file: data/2b0c7d6d57de273795c2fce2e398fdac/cdx.csv
# Choosing 2 random snapshots from data/2b0c7d6d57de273795c2fce2e398fdac/cdx.csv
# Already downloaded 0 snapshots for data/2b0c7d6d57de273795c2fce2e398fdac/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.cool.ne.jp:80/ at timestamp: 20000617020442...
# Snapshot saved at data/2b0c7d6d57de273795c2fce2e398fdac/20000617020442.html
# Downloading snapshot for URL: http://www.cool.ne.jp:80/ at timestamp: 20000621084425...
# Snapshot saved at data/2b0c7d6d57de273795c2fce2e398fdac/20000621084425.html
# Processing CDX file: data/dafd5d5b886aad6e89f76c2135329b73/cdx.csv
# Choosing 2 random snapshots from data/dafd5d5b886aad6e89f76c2135329b73/cdx.csv
# Already downloaded 0 snapshots for data/dafd5d5b886aad6e89f76c2135329b73/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.cplaza.ne.jp:80/ at timestamp: 20000617215458...
# Snapshot saved at data/dafd5d5b886aad6e89f76c2135329b73/20000617215458.html
# Downloading snapshot for URL: http://www.cplaza.ne.jp:80/ at timestamp: 20000520084719...
# Snapshot saved at data/dafd5d5b886aad6e89f76c2135329b73/20000520084719.html
# Processing CDX file: data/e528d0efed0c242afcecb4e6ab1dab65/cdx.csv
# Choosing 2 random snapshots from data/e528d0efed0c242afcecb4e6ab1dab65/cdx.csv
# Already downloaded 0 snapshots for data/e528d0efed0c242afcecb4e6ab1dab65/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.excite.co.jp:80/ at timestamp: 20000619165040...
# Snapshot saved at data/e528d0efed0c242afcecb4e6ab1dab65/20000619165040.html
# Downloading snapshot for URL: http://www.excite.co.jp:80/ at timestamp: 20000511193531...
# Snapshot saved at data/e528d0efed0c242afcecb4e6ab1dab65/20000511193531.html
# Processing CDX file: data/535bc4bb48fda288effb74883d8ab222/cdx.csv
# Choosing 2 random snapshots from data/535bc4bb48fda288effb74883d8ab222/cdx.csv
# Already downloaded 0 snapshots for data/535bc4bb48fda288effb74883d8ab222/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.so-net.ne.jp:80/ at timestamp: 20000619182945...
# Snapshot saved at data/535bc4bb48fda288effb74883d8ab222/20000619182945.html
# Downloading snapshot for URL: http://www2.so-net.ne.jp:80/ at timestamp: 20000620124156...
# Snapshot saved at data/535bc4bb48fda288effb74883d8ab222/20000620124156.html
# Processing CDX file: data/744cf7747fa551bada76b7650c8cfbbb/cdx.csv
# Choosing 2 random snapshots from data/744cf7747fa551bada76b7650c8cfbbb/cdx.csv
# Already downloaded 0 snapshots for data/744cf7747fa551bada76b7650c8cfbbb/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.xaxon.ne.jp:80/ at timestamp: 20000510083345...
# Snapshot saved at data/744cf7747fa551bada76b7650c8cfbbb/20000510083345.html
# Downloading snapshot for URL: http://www.xaxon.ne.jp:80/ at timestamp: 20000520060404...
# Snapshot saved at data/744cf7747fa551bada76b7650c8cfbbb/20000520060404.html
# Processing CDX file: data/b4e722d81eee74c8eeb6c9986698619b/cdx.csv
# Choosing 2 random snapshots from data/b4e722d81eee74c8eeb6c9986698619b/cdx.csv
# Already downloaded 0 snapshots for data/b4e722d81eee74c8eeb6c9986698619b/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www1.din.or.jp:80/ at timestamp: 20000519162718...
# Snapshot saved at data/b4e722d81eee74c8eeb6c9986698619b/20000519162718.html
# Downloading snapshot for URL: http://www.din.or.jp:80/ at timestamp: 20000609142732...
# Snapshot saved at data/b4e722d81eee74c8eeb6c9986698619b/20000609142732.html
# Processing CDX file: data/92932c1e54d99e8c6fac376add3ff8b2/cdx.csv
# Choosing 2 random snapshots from data/92932c1e54d99e8c6fac376add3ff8b2/cdx.csv
# Already downloaded 0 snapshots for data/92932c1e54d99e8c6fac376add3ff8b2/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.bekkoame.ne.jp:80/ at timestamp: 20000510130241...
# Snapshot saved at data/92932c1e54d99e8c6fac376add3ff8b2/20000510130241.html
# Downloading snapshot for URL: http://www.bekkoame.ne.jp:80/ at timestamp: 20000619031246...
# Snapshot saved at data/92932c1e54d99e8c6fac376add3ff8b2/20000619031246.html
# Processing CDX file: data/03e55e791b0c30a0e70b7fcb73d01894/cdx.csv
# Choosing 2 random snapshots from data/03e55e791b0c30a0e70b7fcb73d01894/cdx.csv
# Already downloaded 0 snapshots for data/03e55e791b0c30a0e70b7fcb73d01894/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.geocities.co.jp:80/ at timestamp: 20000609103126...
# Snapshot saved at data/03e55e791b0c30a0e70b7fcb73d01894/20000609103126.html
# Downloading snapshot for URL: http://www.geocities.co.jp:80/ at timestamp: 20000517104647...
# Snapshot saved at data/03e55e791b0c30a0e70b7fcb73d01894/20000517104647.html
# Processing CDX file: data/b3bdcb712d38128626fbb0c76fefed0f/cdx.csv
# Choosing 2 random snapshots from data/b3bdcb712d38128626fbb0c76fefed0f/cdx.csv
# Already downloaded 0 snapshots for data/b3bdcb712d38128626fbb0c76fefed0f/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.plala.or.jp:80/ at timestamp: 20000512000858...
# Snapshot saved at data/b3bdcb712d38128626fbb0c76fefed0f/20000512000858.html
# Downloading snapshot for URL: http://www1.plala.or.jp:80/ at timestamp: 20000408161255...
# Snapshot saved at data/b3bdcb712d38128626fbb0c76fefed0f/20000408161255.html
# Processing CDX file: data/d91d0c585020a45454ea2f383d3632b2/cdx.csv
# Choosing 2 random snapshots from data/d91d0c585020a45454ea2f383d3632b2/cdx.csv
# Already downloaded 0 snapshots for data/d91d0c585020a45454ea2f383d3632b2/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www1.freeweb.ne.jp:80/ at timestamp: 20000510064154...
# Snapshot saved at data/d91d0c585020a45454ea2f383d3632b2/20000510064154.html
# Downloading snapshot for URL: http://www13.freeweb.ne.jp:80/ at timestamp: 20000620143517...
# Snapshot saved at data/d91d0c585020a45454ea2f383d3632b2/20000620143517.html
# Processing CDX file: data/a07316697496dfcb1e4e1dd41e3abec6/cdx.csv
# Choosing 2 random snapshots from data/a07316697496dfcb1e4e1dd41e3abec6/cdx.csv
# Already downloaded 0 snapshots for data/a07316697496dfcb1e4e1dd41e3abec6/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.msn.co.jp:80/ at timestamp: 20000619223245...
# Snapshot saved at data/a07316697496dfcb1e4e1dd41e3abec6/20000619223245.html
# Downloading snapshot for URL: http://www.msn.co.jp:80/ at timestamp: 20000510234119...
# Snapshot saved at data/a07316697496dfcb1e4e1dd41e3abec6/20000510234119.html
# Processing CDX file: data/598ca1bee5d257ac6f3c8477a61c14a2/cdx.csv
# Choosing 2 random snapshots from data/598ca1bee5d257ac6f3c8477a61c14a2/cdx.csv
# Already downloaded 0 snapshots for data/598ca1bee5d257ac6f3c8477a61c14a2/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.biglobe.ne.jp:80/ at timestamp: 20000619041018...
# Snapshot saved at data/598ca1bee5d257ac6f3c8477a61c14a2/20000619041018.html
# Downloading snapshot for URL: http://www.biglobe.ne.jp:80/ at timestamp: 20000510175943...
# Snapshot saved at data/598ca1bee5d257ac6f3c8477a61c14a2/20000510175943.html
# Processing CDX file: data/13e5183cb90bf76e7b92cbe7b2f6980d/cdx.csv
# Choosing 2 random snapshots from data/13e5183cb90bf76e7b92cbe7b2f6980d/cdx.csv
# Already downloaded 0 snapshots for data/13e5183cb90bf76e7b92cbe7b2f6980d/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.impress.co.jp:80/ at timestamp: 20000621231136...
# Snapshot saved at data/13e5183cb90bf76e7b92cbe7b2f6980d/20000621231136.html
# Downloading snapshot for URL: http://www.impress.co.jp:80/ at timestamp: 20000619094720...
# Snapshot saved at data/13e5183cb90bf76e7b92cbe7b2f6980d/20000619094720.html
# Processing CDX file: data/3e907a24a0769b56fc27880bc2db17be/cdx.csv
# Choosing 2 random snapshots from data/3e907a24a0769b56fc27880bc2db17be/cdx.csv
# Already downloaded 0 snapshots for data/3e907a24a0769b56fc27880bc2db17be/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.nikkei.co.jp:80/ at timestamp: 20000621022440...
# Snapshot saved at data/3e907a24a0769b56fc27880bc2db17be/20000621022440.html
# Downloading snapshot for URL: http://www.nikkei.co.jp:80/ at timestamp: 20000621134944...
# Snapshot saved at data/3e907a24a0769b56fc27880bc2db17be/20000621134944.html
# Processing CDX file: data/ecbaa42bb2fc11fb9bcdb25dc35e0147/cdx.csv
# Choosing 2 random snapshots from data/ecbaa42bb2fc11fb9bcdb25dc35e0147/cdx.csv
# Already downloaded 0 snapshots for data/ecbaa42bb2fc11fb9bcdb25dc35e0147/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www2.big.or.jp:80/ at timestamp: 20000621124217...
# Snapshot saved at data/ecbaa42bb2fc11fb9bcdb25dc35e0147/20000621124217.html
# Downloading snapshot for URL: http://www16.big.or.jp:80/ at timestamp: 20000621125942...
# Snapshot saved at data/ecbaa42bb2fc11fb9bcdb25dc35e0147/20000621125942.html
# Processing CDX file: data/f70109946396516168d10e7fc90cf456/cdx.csv
# Choosing 2 random snapshots from data/f70109946396516168d10e7fc90cf456/cdx.csv
# Already downloaded 0 snapshots for data/f70109946396516168d10e7fc90cf456/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.interq.or.jp:80/ at timestamp: 20000510034241...
# Snapshot saved at data/f70109946396516168d10e7fc90cf456/20000510034241.html
# Downloading snapshot for URL: http://www.interq.or.jp:80/ at timestamp: 20000619112039...
# Snapshot saved at data/f70109946396516168d10e7fc90cf456/20000619112039.html
# Processing CDX file: data/6528431ca292d1a40da7085469c250a2/cdx.csv
# Choosing 2 random snapshots from data/6528431ca292d1a40da7085469c250a2/cdx.csv
# Already downloaded 0 snapshots for data/6528431ca292d1a40da7085469c250a2/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.dion.ne.jp:80/ at timestamp: 20000511150713...
# Snapshot saved at data/6528431ca292d1a40da7085469c250a2/20000511150713.html
# Downloading snapshot for URL: http://www.dion.ne.jp:80/ at timestamp: 20000520062237...
# Snapshot saved at data/6528431ca292d1a40da7085469c250a2/20000520062237.html
# Processing CDX file: data/739c420c8f8ff54eba85bdc8dbd297aa/cdx.csv
# Choosing 2 random snapshots from data/739c420c8f8ff54eba85bdc8dbd297aa/cdx.csv
# Already downloaded 0 snapshots for data/739c420c8f8ff54eba85bdc8dbd297aa/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.rim.or.jp:80/ at timestamp: 20000606012532...
# Snapshot saved at data/739c420c8f8ff54eba85bdc8dbd297aa/20000606012532.html
# Downloading snapshot for URL: http://www.rim.or.jp:80/ at timestamp: 20000619091550...
# Snapshot saved at data/739c420c8f8ff54eba85bdc8dbd297aa/20000619091550.html
# Processing CDX file: data/44da265701c915e168eafe0248abb9fa/cdx.csv
# Choosing 2 random snapshots from data/44da265701c915e168eafe0248abb9fa/cdx.csv
# Already downloaded 0 snapshots for data/44da265701c915e168eafe0248abb9fa/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.iijnet.or.jp:80/ at timestamp: 20000408143534...
# Snapshot saved at data/44da265701c915e168eafe0248abb9fa/20000408143534.html
# Downloading snapshot for URL: http://www.iijnet.or.jp:80/ at timestamp: 20000510095252...
# Snapshot saved at data/44da265701c915e168eafe0248abb9fa/20000510095252.html
# Processing CDX file: data/c41512dcac09e2329ebc5c17564e4f6a/cdx.csv
# Choosing 2 random snapshots from data/c41512dcac09e2329ebc5c17564e4f6a/cdx.csv
# Already downloaded 0 snapshots for data/c41512dcac09e2329ebc5c17564e4f6a/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.infoseek.co.jp:80/ at timestamp: 20000407175323...
# Snapshot saved at data/c41512dcac09e2329ebc5c17564e4f6a/20000407175323.html
# Downloading snapshot for URL: http://www.infoseek.co.jp:80/ at timestamp: 20000621024404...
# Snapshot saved at data/c41512dcac09e2329ebc5c17564e4f6a/20000621024404.html
# Processing CDX file: data/02efb45e70adeb94cccd008670559250/cdx.csv
# Choosing 2 random snapshots from data/02efb45e70adeb94cccd008670559250/cdx.csv
# Already downloaded 0 snapshots for data/02efb45e70adeb94cccd008670559250/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.nifty.com:80/ at timestamp: 20000620153144...
# Snapshot saved at data/02efb45e70adeb94cccd008670559250/20000620153144.html
# Downloading snapshot for URL: http://www.nifty.com:80/ at timestamp: 20000408214322...
# Snapshot saved at data/02efb45e70adeb94cccd008670559250/20000408214322.html
# Processing CDX file: data/9dc00b08361ebb7d937f428bbc6d4fe1/cdx.csv
# Choosing 2 random snapshots from data/9dc00b08361ebb7d937f428bbc6d4fe1/cdx.csv
# Already downloaded 0 snapshots for data/9dc00b08361ebb7d937f428bbc6d4fe1/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.ne.jp:80/ at timestamp: 20000408230754...
# Snapshot saved at data/9dc00b08361ebb7d937f428bbc6d4fe1/20000408230754.html
# Processing CDX file: data/4c46800776c8bb778889fda89a6a6b90/cdx.csv
# Choosing 2 random snapshots from data/4c46800776c8bb778889fda89a6a6b90/cdx.csv
# Already downloaded 0 snapshots for data/4c46800776c8bb778889fda89a6a6b90/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www2.mbn.or.jp:80/ at timestamp: 20000621100012...
# Snapshot saved at data/4c46800776c8bb778889fda89a6a6b90/20000621100012.html
# Downloading snapshot for URL: http://www.mbn.or.jp:80/ at timestamp: 20000618010157...
# Snapshot saved at data/4c46800776c8bb778889fda89a6a6b90/20000618010157.html
# Processing CDX file: data/830ddf4e59a7f3c5ada3465445c8b9fa/cdx.csv
# Choosing 2 random snapshots from data/830ddf4e59a7f3c5ada3465445c8b9fa/cdx.csv
# Already downloaded 0 snapshots for data/830ddf4e59a7f3c5ada3465445c8b9fa/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.rakuten.co.jp:80/ at timestamp: 20000511090918...
# Snapshot saved at data/830ddf4e59a7f3c5ada3465445c8b9fa/20000511090918.html
# Downloading snapshot for URL: http://www.rakuten.co.jp:80/ at timestamp: 20000511100632...
# Snapshot saved at data/830ddf4e59a7f3c5ada3465445c8b9fa/20000511100632.html
# Processing CDX file: data/a26aface8846a624b68d7441323ad6ea/cdx.csv
# Choosing 2 random snapshots from data/a26aface8846a624b68d7441323ad6ea/cdx.csv
# Already downloaded 0 snapshots for data/a26aface8846a624b68d7441323ad6ea/cdx.csv
# Number of new snapshots to download: 2
# Processing CDX file: data/58e98dfc94996a1d7f97f79d7f6ba9ed/cdx.csv
# Choosing 2 random snapshots from data/58e98dfc94996a1d7f97f79d7f6ba9ed/cdx.csv
# Already downloaded 0 snapshots for data/58e98dfc94996a1d7f97f79d7f6ba9ed/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.highway.ne.jp:80/ at timestamp: 20000511212508...
# Snapshot saved at data/58e98dfc94996a1d7f97f79d7f6ba9ed/20000511212508.html
# Processing CDX file: data/db84cb0d40b9f169a4643ee20c022d40/cdx.csv
# Choosing 2 random snapshots from data/db84cb0d40b9f169a4643ee20c022d40/cdx.csv
# Already downloaded 0 snapshots for data/db84cb0d40b9f169a4643ee20c022d40/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www1.neweb.ne.jp:80/ at timestamp: 20000621102446...
# Snapshot saved at data/db84cb0d40b9f169a4643ee20c022d40/20000621102446.html
# Downloading snapshot for URL: http://www1.neweb.ne.jp:80/ at timestamp: 20000621211222...
# Snapshot saved at data/db84cb0d40b9f169a4643ee20c022d40/20000621211222.html
# Processing CDX file: data/bef081a841799df11166f1d69851d534/cdx.csv
# Choosing 2 random snapshots from data/bef081a841799df11166f1d69851d534/cdx.csv
# Already downloaded 0 snapshots for data/bef081a841799df11166f1d69851d534/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.hi-ho.ne.jp:80/ at timestamp: 20000510144721...
# Snapshot saved at data/bef081a841799df11166f1d69851d534/20000510144721.html
# Processing CDX file: data/8fe3236993fff804b28195320880f277/cdx.csv
# Choosing 2 random snapshots from data/8fe3236993fff804b28195320880f277/cdx.csv
# Already downloaded 0 snapshots for data/8fe3236993fff804b28195320880f277/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.tripod.co.jp:80/ at timestamp: 20000612070917...
# Snapshot saved at data/8fe3236993fff804b28195320880f277/20000612070917.html
# Downloading snapshot for URL: http://www.tripod.co.jp:80/ at timestamp: 20000511174013...
# Snapshot saved at data/8fe3236993fff804b28195320880f277/20000511174013.html
# Processing CDX file: data/e5fd6205dda399e39d9c3b055734f83f/cdx.csv
# Choosing 2 random snapshots from data/e5fd6205dda399e39d9c3b055734f83f/cdx.csv
# Already downloaded 0 snapshots for data/e5fd6205dda399e39d9c3b055734f83f/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.yahoo.co.jp:80/ at timestamp: 20000510134659...
# Snapshot saved at data/e5fd6205dda399e39d9c3b055734f83f/20000510134659.html
# Downloading snapshot for URL: http://www.yahoo.co.jp:80/ at timestamp: 20000510093745...
# Snapshot saved at data/e5fd6205dda399e39d9c3b055734f83f/20000510093745.html
# Processing CDX file: data/19d85e44f084d4b4d09373bfba3f576c/cdx.csv
# Choosing 2 random snapshots from data/19d85e44f084d4b4d09373bfba3f576c/cdx.csv
# Already downloaded 0 snapshots for data/19d85e44f084d4b4d09373bfba3f576c/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.3web.ne.jp:80/ at timestamp: 20000511122128...
# Snapshot saved at data/19d85e44f084d4b4d09373bfba3f576c/20000511122128.html
# Processing CDX file: data/245505630037d8a520036ff590e3cd2e/cdx.csv
# Choosing 2 random snapshots from data/245505630037d8a520036ff590e3cd2e/cdx.csv
# Already downloaded 0 snapshots for data/245505630037d8a520036ff590e3cd2e/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.nifty.ne.jp:80/ at timestamp: 20000429022625...
# Snapshot saved at data/245505630037d8a520036ff590e3cd2e/20000429022625.html
# Processing CDX file: data/9cec14420da076836a3fdc6e832b9b92/cdx.csv
# Choosing 2 random snapshots from data/9cec14420da076836a3fdc6e832b9b92/cdx.csv
# Already downloaded 0 snapshots for data/9cec14420da076836a3fdc6e832b9b92/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.goo.ne.jp:80/ at timestamp: 20000510185419...
# Snapshot saved at data/9cec14420da076836a3fdc6e832b9b92/20000510185419.html
# Downloading snapshot for URL: http://www.goo.ne.jp:80/? at timestamp: 20000510202907...
# Snapshot saved at data/9cec14420da076836a3fdc6e832b9b92/20000510202907.html
# Processing CDX file: data/b53ae61a77ead6d7949a01a8b562d704/cdx.csv
# Choosing 2 random snapshots from data/b53ae61a77ead6d7949a01a8b562d704/cdx.csv
# Already downloaded 0 snapshots for data/b53ae61a77ead6d7949a01a8b562d704/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.infoweb.ne.jp:80/ at timestamp: 20000520085104...
# Snapshot saved at data/b53ae61a77ead6d7949a01a8b562d704/20000520085104.html
# Processing CDX file: data/e51f896069b124422722693994038696/cdx.csv
# Choosing 2 random snapshots from data/e51f896069b124422722693994038696/cdx.csv
# Already downloaded 0 snapshots for data/e51f896069b124422722693994038696/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.asahi-net.or.jp:80/ at timestamp: 20000622022611...
# Snapshot saved at data/e51f896069b124422722693994038696/20000622022611.html
# Downloading snapshot for URL: http://www.asahi-net.or.jp:80/ at timestamp: 20000619013337...
# Snapshot saved at data/e51f896069b124422722693994038696/20000619013337.html
# Processing CDX file: data/94376871a447d09d0041a67dfcad87ec/cdx.csv
# Choosing 2 random snapshots from data/94376871a447d09d0041a67dfcad87ec/cdx.csv
# Already downloaded 0 snapshots for data/94376871a447d09d0041a67dfcad87ec/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.justnet.ne.jp:80/ at timestamp: 20000510012408...
# Snapshot saved at data/94376871a447d09d0041a67dfcad87ec/20000510012408.html
# Downloading snapshot for URL: http://www.justnet.ne.jp:80/ at timestamp: 20000622034624...
# Snapshot saved at data/94376871a447d09d0041a67dfcad87ec/20000622034624.html
# Processing CDX file: data/8114c30ebe6c67f874c6bc24c94aaeb7/cdx.csv
# Choosing 2 random snapshots from data/8114c30ebe6c67f874c6bc24c94aaeb7/cdx.csv
# Already downloaded 0 snapshots for data/8114c30ebe6c67f874c6bc24c94aaeb7/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www3.nikkeibp.co.jp:80/ at timestamp: 20000603025009...
# Snapshot saved at data/8114c30ebe6c67f874c6bc24c94aaeb7/20000603025009.html
# Downloading snapshot for URL: http://www77.nikkeibp.co.jp:80/ at timestamp: 20000528235554...
# Snapshot saved at data/8114c30ebe6c67f874c6bc24c94aaeb7/20000528235554.html
# Processing CDX file: data/d4bffe3267a972738ae687eb26cf43d8/cdx.csv
# Choosing 2 random snapshots from data/d4bffe3267a972738ae687eb26cf43d8/cdx.csv
# Already downloaded 0 snapshots for data/d4bffe3267a972738ae687eb26cf43d8/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.tcup.com:80/? at timestamp: 20000408155247...
# Snapshot saved at data/d4bffe3267a972738ae687eb26cf43d8/20000408155247.html
# Downloading snapshot for URL: http://www.tcup.com:80/ at timestamp: 20000621145949...
# Snapshot saved at data/d4bffe3267a972738ae687eb26cf43d8/20000621145949.html
# Processing CDX file: data/893d39529188742980cc3522ae2b7df9/cdx.csv
# Choosing 2 random snapshots from data/893d39529188742980cc3522ae2b7df9/cdx.csv
# Already downloaded 0 snapshots for data/893d39529188742980cc3522ae2b7df9/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www2.odn.ne.jp:80/ at timestamp: 20000520034657...
# Snapshot saved at data/893d39529188742980cc3522ae2b7df9/20000520034657.html
# Downloading snapshot for URL: http://odn.ne.jp:80/ at timestamp: 20000520065813...
# Snapshot saved at data/893d39529188742980cc3522ae2b7df9/20000520065813.html
# Processing CDX file: data/0a244c72332fad89ea19d23938d61f41/cdx.csv
# Choosing 2 random snapshots from data/0a244c72332fad89ea19d23938d61f41/cdx.csv
# Already downloaded 0 snapshots for data/0a244c72332fad89ea19d23938d61f41/cdx.csv
# Number of new snapshots to download: 2
# Processing CDX file: data/2f856f8fd94db69056ec0c40d9723ff5/cdx.csv
# Choosing 2 random snapshots from data/2f856f8fd94db69056ec0c40d9723ff5/cdx.csv
# Already downloaded 0 snapshots for data/2f856f8fd94db69056ec0c40d9723ff5/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.ocn.ne.jp:80/ at timestamp: 20000620192544...
# Snapshot saved at data/2f856f8fd94db69056ec0c40d9723ff5/20000620192544.html
# Downloading snapshot for URL: http://www.ocn.ne.jp:80/ at timestamp: 20000511142256...
# Snapshot saved at data/2f856f8fd94db69056ec0c40d9723ff5/20000511142256.html
# Processing CDX file: data/b5ad3c7900e51a0eb8c470eccbc6545e/cdx.csv
# Choosing 2 random snapshots from data/b5ad3c7900e51a0eb8c470eccbc6545e/cdx.csv
# Already downloaded 0 snapshots for data/b5ad3c7900e51a0eb8c470eccbc6545e/cdx.csv
# Number of new snapshots to download: 2
# Downloading snapshot for URL: http://www.iij4u.or.jp:80/ at timestamp: 20000616230950...
# Snapshot saved at data/b5ad3c7900e51a0eb8c470eccbc6545e/20000616230950.html
# Downloading snapshot for URL: http://www.iij4u.or.jp:80/ at timestamp: 20000621075444...
# Snapshot saved at data/b5ad3c7900e51a0eb8c470eccbc6545e/20000621075444.html

# %%
# Search for all downloaded HTML files and see if they contain the element <frameset>
html_files = Path("data").glob("*/**/*.html")
for html_file in html_files:
    try:
        with open(html_file, 'r', encoding='utf-8') as file:
            content = file.read()
            if '<frameset' in content.lower(): # Check for <frameset> in a case-insensitive manner
                print(f"Found <frameset> in {html_file}")
    except Exception as e:
        print(f"Error reading {html_file}: {e}")
# Out:
# Found <frameset> in data/b3bdcb712d38128626fbb0c76fefed0f/20000512000858.html
# Found <frameset> in data/58e98dfc94996a1d7f97f79d7f6ba9ed/20000511212508.html
# Found <frameset> in data/d4bffe3267a972738ae687eb26cf43d8/20000621145949.html
# Found <frameset> in data/d4bffe3267a972738ae687eb26cf43d8/20000408155247.html

# %%
# Check all downloaded CDX files and see how many snapshots are captured in the month of 200005
cdx_files = Path("data").glob("*/cdx.csv")

snapshot_count = 0

for cdx_file in cdx_files:
    print(f"Processing CDX file: {cdx_file}")
    # read the csv file and count the number of snapshots in the month of 200005

    with open(cdx_file, 'r', encoding='utf-8') as file:
        reader = csv.reader(file, delimiter=' ')
        snapshots = list(reader)
        unique_snapshots = {snapshot[5]: snapshot for snapshot in snapshots}.values()
        for row in unique_snapshots:
            if len(row) >= 3:
                timestamp = row[1]
                if timestamp.startswith('200005'):
                    snapshot_count += 1 

print(f"Total number of snapshots captured in the month of 200005: {snapshot_count}")
# Out:
# Processing CDX file: data/a65a310ffdf9e798db8143f21de138ef/cdx.csv
# Processing CDX file: data/425b80310c0dcf16ac09e4c76a273734/cdx.csv
# Processing CDX file: data/5d5f85669bd24bde374e4e2da080b205/cdx.csv
# Processing CDX file: data/439868a9c18529515a0be3529bfb20aa/cdx.csv
# Processing CDX file: data/2b0c7d6d57de273795c2fce2e398fdac/cdx.csv
# Processing CDX file: data/dafd5d5b886aad6e89f76c2135329b73/cdx.csv
# Processing CDX file: data/e528d0efed0c242afcecb4e6ab1dab65/cdx.csv
# Processing CDX file: data/535bc4bb48fda288effb74883d8ab222/cdx.csv
# Processing CDX file: data/744cf7747fa551bada76b7650c8cfbbb/cdx.csv
# Processing CDX file: data/b4e722d81eee74c8eeb6c9986698619b/cdx.csv
# Processing CDX file: data/92932c1e54d99e8c6fac376add3ff8b2/cdx.csv
# Processing CDX file: data/03e55e791b0c30a0e70b7fcb73d01894/cdx.csv
# Processing CDX file: data/b3bdcb712d38128626fbb0c76fefed0f/cdx.csv
# Processing CDX file: data/d91d0c585020a45454ea2f383d3632b2/cdx.csv
# Processing CDX file: data/a07316697496dfcb1e4e1dd41e3abec6/cdx.csv
# Processing CDX file: data/598ca1bee5d257ac6f3c8477a61c14a2/cdx.csv
# Processing CDX file: data/13e5183cb90bf76e7b92cbe7b2f6980d/cdx.csv
# Processing CDX file: data/3e907a24a0769b56fc27880bc2db17be/cdx.csv
# Processing CDX file: data/ecbaa42bb2fc11fb9bcdb25dc35e0147/cdx.csv
# Processing CDX file: data/f70109946396516168d10e7fc90cf456/cdx.csv
# Processing CDX file: data/6528431ca292d1a40da7085469c250a2/cdx.csv
# Processing CDX file: data/739c420c8f8ff54eba85bdc8dbd297aa/cdx.csv
# Processing CDX file: data/44da265701c915e168eafe0248abb9fa/cdx.csv
# Processing CDX file: data/c41512dcac09e2329ebc5c17564e4f6a/cdx.csv
# Processing CDX file: data/02efb45e70adeb94cccd008670559250/cdx.csv
# Processing CDX file: data/9dc00b08361ebb7d937f428bbc6d4fe1/cdx.csv
# Processing CDX file: data/4c46800776c8bb778889fda89a6a6b90/cdx.csv
# Processing CDX file: data/830ddf4e59a7f3c5ada3465445c8b9fa/cdx.csv
# Processing CDX file: data/a26aface8846a624b68d7441323ad6ea/cdx.csv
# Processing CDX file: data/58e98dfc94996a1d7f97f79d7f6ba9ed/cdx.csv
# Processing CDX file: data/db84cb0d40b9f169a4643ee20c022d40/cdx.csv
# Processing CDX file: data/bef081a841799df11166f1d69851d534/cdx.csv
# Processing CDX file: data/8fe3236993fff804b28195320880f277/cdx.csv
# Processing CDX file: data/e5fd6205dda399e39d9c3b055734f83f/cdx.csv
# Processing CDX file: data/19d85e44f084d4b4d09373bfba3f576c/cdx.csv
# Processing CDX file: data/245505630037d8a520036ff590e3cd2e/cdx.csv
# Processing CDX file: data/9cec14420da076836a3fdc6e832b9b92/cdx.csv
# Processing CDX file: data/b53ae61a77ead6d7949a01a8b562d704/cdx.csv
# Processing CDX file: data/e51f896069b124422722693994038696/cdx.csv
# Processing CDX file: data/94376871a447d09d0041a67dfcad87ec/cdx.csv
# Processing CDX file: data/8114c30ebe6c67f874c6bc24c94aaeb7/cdx.csv
# Processing CDX file: data/d4bffe3267a972738ae687eb26cf43d8/cdx.csv
# Processing CDX file: data/893d39529188742980cc3522ae2b7df9/cdx.csv
# Processing CDX file: data/0a244c72332fad89ea19d23938d61f41/cdx.csv
# Processing CDX file: data/2f856f8fd94db69056ec0c40d9723ff5/cdx.csv
# Processing CDX file: data/b5ad3c7900e51a0eb8c470eccbc6545e/cdx.csv
# Total number of snapshots captured in the month of 200005: 167
