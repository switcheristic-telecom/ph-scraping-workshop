# %%
import requests
from urllib.parse import urlparse
from requests.exceptions import RequestException

def retrieve_archive_html(original_url: str, timestamp: str):
    """
    Downloads the HTML content of a URL from the Wayback Machine at a specific timestamp.

    :param original_url: The original URL to be archived.
    :param timestamp: The timestamp in the format 'YYYYMMDDhhmmss'.
    :return: The HTML content of the archived page.
    """

    wayback_url = f"https://web.archive.org/web/{timestamp}id_/{original_url}"
    
    try:
        response = requests.get(wayback_url, timeout=10)
        response.encoding = response.apparent_encoding
        response.raise_for_status()
        print(response.headers)
        print(response.encoding)
        return response.text
    except RequestException as e:
        raise RuntimeError(f"Failed to download archive: {e}")

# %%
test_url = 'yahoo.co.jp'
test_timestamp = '20000304173408' 
try:
    html_content = retrieve_archive_html(test_url, test_timestamp)
    print("HTML content retrieved successfully.")
    print(html_content[:1000])  # Print the first 500 characters of the HTML content
except RuntimeError as e:
    print(f"Error: {e}")
# Out:
# {'Server': 'nginx', 'Date': 'Sun, 15 Jun 2025 23:05:23 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'x-archive-orig-content-length': '21071', 'cache-control': 'max-age=1800', 'memento-datetime': 'Sat, 04 Mar 2000 17:34:08 GMT', 'link': '<http://www.yahoo.co.jp:80/>; rel="original", <https://web.archive.org/web/timemap/link/http://www.yahoo.co.jp:80/>; rel="timemap"; type="application/link-format", <https://web.archive.org/web/http://www.yahoo.co.jp:80/>; rel="timegate", <https://web.archive.org/web/19961120065342/http://www03.yahoo.co.jp:80/>; rel="first memento"; datetime="Wed, 20 Nov 1996 06:53:42 GMT", <https://web.archive.org/web/20000304134504/http://www.yahoo.co.jp:80/>; rel="prev memento"; datetime="Sat, 04 Mar 2000 13:45:04 GMT", <https://web.archive.org/web/20000304173408/http://www.yahoo.co.jp:80/>; rel="memento"; datetime="Sat, 04 Mar 2000 17:34:08 GMT", <https://web.archive.org/web/20000408221304/http://www.yahoo.co.jp:80/>; rel="next memento"; datetime="Sat, 08 Apr 2000 22:13:04 GMT", <https://web.archive.org/web/20250615123935/https://www.yahoo.co.jp/>; rel="last memento"; datetime="Sun, 15 Jun 2025 12:39:35 GMT"', 'content-security-policy': "default-src 'self' 'unsafe-eval' 'unsafe-inline' data: blob: archive.org web.archive.org web-static.archive.org wayback-api.archive.org athena.archive.org analytics.archive.org pragma.archivelab.org wwwb-events.archive.org", 'x-archive-src': 'green-000044-20000228185217-952155265-c/green-000048-20000228185217-952191222.arc.gz', 'server-timing': 'captures_list;dur=4.158782, exclusion.robots;dur=0.188962, exclusion.robots.policy;dur=0.119492, esindex;dur=0.078106, cdx.remote;dur=362.948840, LoadShardBlock;dur=2173.832770, PetaboxLoader3.datanode;dur=1136.765232, PetaboxLoader3.resolve;dur=526.849763, load_resource;dur=163.181994, TR;dur=0,Tw;dur=0,Tc;dur=1, HIT', 'x-app-server': 'wwwb-app226', 'x-ts': '200', 'x-tr': '3243', 'X-location': 'All', 'X-RL': '0', 'X-NA': '0', 'X-Page-Cache': 'HIT', 'X-NID': '-', 'Referrer-Policy': 'no-referrer-when-downgrade', 'Permissions-Policy': 'interest-cohort=()', 'Content-Encoding': 'gzip'}
# EUC-JP
# HTML content retrieved successfully.
# <HTML>
# <HEAD>
# <!--��-->
# <TITLE>Yahoo! JAPAN </TITLE>
# <script language="javascript">
#
# <!--
# var remote = null;
# function remoteStart() {
#   remote = window.open('', 'yahooRemote', 'width=250,height=300,scrollbars=1,resizable=yes');
#   if (remote != null) {
#     if (remote.opener == null) {
#       remote.opener = self;
#     }
#     remote.location.href = 'http://www.yahoo.co.jp/remote/?http://www.yahoo.co.jp/remote/remote.html';
#   }
# }
# // -->
#
# </script>
# </HEAD>
# <BODY>
#
# <base href="http://www.yahoo.co.jp/">
#
# <map name="top">
# <area shape=rect coords="69,0,127,58" href="http://www.yahoo.co.jp/new/" alt="新着情報">
# <area shape=rect coords="128,0,186,58" href="http://pager.yahoo.co.jp/" alt="ページャー">
# <area shape=rect coords="187,0,419,58" href="http://www.yahoo.co.jp/" alt="Yahoo! JAPAN">
# <area shape=rect coords="420,0,478,58" href="http://my.yahoo.co.jp/" alt="My Yahoo!">
# <area shape=rect coords="479,0,537,58" href="http://www.yahoo.co.jp/docs/howto/index.htm" alt="ヘルプ">
# </map>
#
# <center><a href="/bin/top3"

# %%
# detect html content encoding
import chardet
encoding = chardet.detect(html_content)
print(f"Detected encoding: {encoding['encoding']} with confidence {encoding['confidence']:.2f}")
# Out:
# Detected encoding: EUC-JP with confidence 0.99

# %%
from pathlib import Path
import random
import csv
import time

# Go through each folder in data/, check the content of the cdx.csv file, select 10 URLs to download. 

for folder in Path("data").iterdir():
    if folder.is_dir():
        print(f"Processing folder: {folder}")
        cdx_file = folder / "cdx.csv"
        downloaded_files = [file for file in folder.glob("*.html") if file.is_file()]
        if cdx_file.exists():
            with open(cdx_file, 'r', encoding='utf-8') as file:
                reader = csv.reader(file, delimiter=' ')
                # make reader into a list and filter rows
                url_rows = []
                for row in reader:
                    print(f"Processing row: {row}")
                    # Check if the row has enough columns and the status code is 200
                    if len(row) > 4 and row[4] == '200':
                        url_rows.append(row)
                print(f"Found {len(url_rows)} valid URLs in {cdx_file}.")
            # Filter out URLs that have already been downloaded
            url_rows = [row for row in url_rows if not any(file.stem == row[0] for file in downloaded_files)]
            print(f"Filtered down to {len(url_rows)} URLs that have not been downloaded yet.")

            if url_rows:
                selected_rows = random.sample(url_rows, min(10, len(url_rows)))
                for row in selected_rows:
                    url = row[2]
                    timestamp = row[1]
                    try:
                        html_content = retrieve_archive_html(url, timestamp)
                        time.sleep(5)  # Sleep to avoid hitting the server too hard
                        # Save the HTML content to a file
                        html_file_path = folder / f"{row[0]}.html"
                        with open(f'{folder}/{timestamp}.html', 'w', encoding='utf-8') as html_file:
                            html_file.write(html_content)
                        print(f"Downloaded {url} at {timestamp} to {html_file_path}")
                    except RuntimeError as e:
                        print(f"Error downloading {url} at {timestamp}: {e}")
        else:
            print(f"No cdx.csv found in {folder}")
# Out:
# Processing folder: data/1
# Processing row: ['jp,co,yahoo)/', '20000229163149', 'http://www121.yahoo.co.jp:80/', 'text/html', '200', '7OY5HCVOJALTGSUPICD5HN5AYQMVZAXI', '5282']
# Processing row: ['jp,co,yahoo)/', '20000229171208', 'http://www.yahoo.co.jp:80/?', 'text/plain', '302', 'VXEDWGPHSNERWHDOUD6YWRWNT4ZOLEX4', '120']
# Processing row: ['jp,co,yahoo)/', '20000301054711', 'http://www119.yahoo.co.jp:80/', 'text/html', '200', 'DQCTETZ3VATNVTTOBLXJVWNUYCFAY4V4', '5285']
# Processing row: ['jp,co,yahoo)/', '20000301060532', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'DQCTETZ3VATNVTTOBLXJVWNUYCFAY4V4', '5279']
# Processing row: ['jp,co,yahoo)/', '20000301070501', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'FRPHCDHKU33VGEG4A6D3FLPSDMBG3HP5', '5244']
# Processing row: ['jp,co,yahoo)/', '20000301081906', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'DA7FCQ6NDKG5BL6EUPY65N6SFREKHCJ6', '5243']
# Processing row: ['jp,co,yahoo)/', '20000301143405', 'http://www.yahoo.co.jp:80/', 'text/html', '200', '3PVDD6NH3RGM23EWODNQID5OL2L5P765', '5258']
# Processing row: ['jp,co,yahoo)/', '20000301173328', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'UUEL7OARSQVAAVBIVEUPWCMR5DZ33BVI', '5383']
# Processing row: ['jp,co,yahoo)/', '20000301190016', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'UUEL7OARSQVAAVBIVEUPWCMR5DZ33BVI', '5380']
# Processing row: ['jp,co,yahoo)/', '20000301205833', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'UUEL7OARSQVAAVBIVEUPWCMR5DZ33BVI', '5383']
# Processing row: ['jp,co,yahoo)/', '20000303012603', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'X5LVFBCIMLS7P6PHINVGJFNFPC2V2ZAW', '5441']
# Processing row: ['jp,co,yahoo)/', '20000303061950', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'W2L7QX55DTH6RGRNTSID4ZYR67AFDHUX', '5468']
# Processing row: ['jp,co,yahoo)/', '20000303064251', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'W2L7QX55DTH6RGRNTSID4ZYR67AFDHUX', '5468']
# Processing row: ['jp,co,yahoo)/', '20000303092548', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'YYOCSSBX46S5ZWSVZHHRRKFBNHQATHAB', '5510']
# Processing row: ['jp,co,yahoo)/', '20000303111055', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'YYOCSSBX46S5ZWSVZHHRRKFBNHQATHAB', '5509']
# Processing row: ['jp,co,yahoo)/', '20000303160754', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'V2QO4Y6GFMA6Z5RM6RZ2TJJLKLLULD2Y', '5435']
# Processing row: ['jp,co,yahoo)/', '20000303181345', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'V2QO4Y6GFMA6Z5RM6RZ2TJJLKLLULD2Y', '5435']
# Processing row: ['jp,co,yahoo)/', '20000304004112', 'http://www.yahoo.co.jp:80/', 'text/html', '200', '26S6BY2S52P3QDFW633MFRMLYC2YUNIT', '5432']
# Processing row: ['jp,co,yahoo)/', '20000304104924', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'WV6ZYAKWJ5TOYW6XHWTMHNKHEM6MUAJL', '5437']
# Processing row: ['jp,co,yahoo)/', '20000304104939', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'WV6ZYAKWJ5TOYW6XHWTMHNKHEM6MUAJL', '5437']
# Processing row: ['jp,co,yahoo)/', '20000304111245', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'WV6ZYAKWJ5TOYW6XHWTMHNKHEM6MUAJL', '5436']
# Processing row: ['jp,co,yahoo)/', '20000304134504', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 
 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'AMIUZUIL7NCJCPFK22JRHLHADHIUGWHY', '5366']
# Processing row: ['jp,co,yahoo)/', '20000511085920', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'AMIUZUIL7NCJCPFK22JRHLHADHIUGWHY', '5364']
# Processing row: ['jp,co,yahoo)/', '20000511110235', 'http://www00.yahoo.co.jp:80/', 'text/html', '200', 'DUM5WFDJ5CEWTUFUZETLVWLRBCDSTXVC', '5432']
# Processing row: ['jp,co,yahoo)/', '20000511114238', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'GAXKVMJEANP27HFPKNI2IN2TNTMZEFJI', '5369']
# Processing row: ['jp,co,yahoo)/', '20000511131917', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'GAXKVMJEANP27HFPKNI2IN2TNTMZEFJI', '5370']
# Processing row: ['jp,co,yahoo)/', '20000511140206', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'GAXKVMJEANP27HFPKNI2IN2TNTMZEFJI', '5369']
# Processing row: ['jp,co,yahoo)/', '20000511150440', 'http://www.yahoo.co.jp:80/?', 'text/plain', '302', 'VXEDWGPHSNERWHDOUD6YWRWNT4ZOLEX4', '120']
# Processing row: ['jp,co,yahoo)/', '20000511190656', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'GAXKVMJEANP27HFPKNI2IN2TNTMZEFJI', '5369']
# Processing row: ['jp,co,yahoo)/', '20000511200322', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'GAXKVMJEANP27HFPKNI2IN2TNTMZEFJI', '5368']
# Processing row: ['jp,co,yahoo)/', '20000511210239', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'GAXKVMJEANP27HFPKNI2IN2TNTMZEFJI', '5369']
# Processing row: ['jp,co,yahoo)/', '20000511230149', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'GAXKVMJEANP27HFPKNI2IN2TNTMZEFJI', '5370']
# Processing row: ['jp,co,yahoo)/', '20000512010122', 'http://www117.yahoo.co.jp:80/', 'text/html', '200', 'GAXKVMJEANP27HFPKNI2IN2TNTMZEFJI', '5373']
# Processing row: ['jp,co,yahoo)/', '20000519230412', 'http://www.yahoo.co.jp:80/', 'text/html', '200', '32AQJKIMZFZRJNY6GJOTE6WUSIVJV6YE', '5333']
# Processing row: ['jp,co,yahoo)/', '20000614070212', 'http://www112.yahoo.co.jp:80/', 'text/html', '200', 'VPESGX7BVGUW3C4ZUO5BCTENAXK44T35', '5556']
# Processing row: ['jp,co,yahoo)/', '20000614204332', 'http://www34.yahoo.co.jp:80/', 'text/html', '200', 'PDJTRVFETGWLRPH3XENQNZ3MMS7LAHMU', '4007']
# Processing row: ['jp,co,yahoo)/', '20000619030931', 'http://www.yahoo.co.jp:80/', 'text/html', '200', '56OKODYETW3NNQZB2H44PTYA2LZP7RLX', '5556']
# Processing row: ['jp,co,yahoo)/', '20000619043747', 'http://www.yahoo.co.jp:80/', 'text/html', '200', '56OKODYETW3NNQZB2H44PTYA2LZP7RLX', '5557']
# Processing row: ['jp,co,yahoo)/', '20000619092157', 'http://www.yahoo.co.jp:80/', 'text/html', '200', '2UECOKANH57UAXTUFLJNPSZCAKJQUIZB', '5582']
# Processing row: ['jp,co,yahoo)/', '20000619092751', 'http://www.yahoo.co.jp:80/', 'text/html', '200', '2UECOKANH57UAXTUFLJNPSZCAKJQUIZB', '5582']
# Processing row: ['jp,co,yahoo)/', '20000619113634', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'EDB7MIY55LCHIUUEDC4EAZN4PNBEYAPD', '5583']
# Processing row: ['jp,co,yahoo)/', '20000619121629', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'EDB7MIY55LCHIUUEDC4EAZN4PNBEYAPD', '5580']
# Processing row: ['jp,co,yahoo)/', '20000619134137', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'EDB7MIY55LCHIUUEDC4EAZN4PNBEYAPD', '5583']
# Processing row: ['jp,co,yahoo)/', '20000619155647', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'EDB7MIY55LCHIUUEDC4EAZN4PNBEYAPD', '5582']
# Processing row: ['jp,co,yahoo)/', '20000619173341', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'EDB7MIY55LCHIUUEDC4EAZN4PNBEYAPD', '5583']
# Processing row: ['jp,co,yahoo)/', '20000619192353', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'EDB7MIY55LCHIUUEDC4EAZN4PNBEYAPD', '5582']
# Processing row: ['jp,co,yahoo)/', '20000619193720', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'OL7M3O4NSXKBSOUZ5A7HBCFPOAAK45XT', '5585']
# Processing row: ['jp,co,yahoo)/', '20000619193803', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'OL7M3O4NSXKBSOUZ5A7HBCFPOAAK45XT', '5585']
# Processing row: ['jp,co,yahoo)/', '20000619200723', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'OL7M3O4NSXKBSOUZ5A7HBCFPOAAK45XT', '5584']
# Processing row: ['jp,co,yahoo)/', '20000619224000', 'http://www.yahoo.co.jp:80/?', 'text/plain', '302', 'VXEDWGPHSNERWHDOUD6YWRWNT4ZOLEX4', '121']
# Processing row: ['jp,co,yahoo)/', '20000620032506', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'CS6B7QC7ZHX3EYV3FGGDBTZ2A54FSOAF', '5581']
# Processing row: ['jp,co,yahoo)/', '20000620042523', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'RFYGBZS4CUY74752UBJZMLQ74LBMMNSP', '5594']
# Processing row: ['jp,co,yahoo)/', '20000620050159', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'RFYGBZS4CUY74752UBJZMLQ74LBMMNSP', '5594']
# Processing row: ['jp,co,yahoo)/', '20000620083906', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'YSZOCVTHN5FGUGHMUFR7QCEXBUCC3WXH', '5628']
# Processing row: ['jp,co,yahoo)/', '20000620103218', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'HPV7ZXH5BPZ3EY36QC35GDYNWHE65H7Y', '5594']
# Processing row: ['jp,co,yahoo)/', '20000620154606', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'HJO43SKXLOZZBCIOFEVYC3MHFZLGJ7JV', '5597']
# Processing row: ['jp,co,yahoo)/', '20000620155350', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'HJO43SKXLOZZBCIOFEVYC3MHFZLGJ7JV', '5596']
# Processing row: ['jp,co,yahoo)/', '20000620163658', 'http://www00.yahoo.co.jp:80/', 'text/html', '200', 'YKU5ENAVO5MSJO3KD2ZPJO3E76GSIIXU', '2308']
# Processing row: ['jp,co,yahoo)/', '20000621175401', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'KDL5RHL47GIOVVBC27YBUUCQBHTPS3KX', '5584']
# Processing row: ['jp,co,yahoo)/', '20000707233706', 'http://www114.yahoo.co.jp:80/', 'text/html', '200', 'BGRVKOO3XLOGNS4VPKTKPTBDDT7HN3DS', '5580']
# Processing row: ['jp,co,yahoo)/', '20000711003607', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'BV4ZKGE43UHLIUFFYLLGSA3BF6YUGW6R', '5509']
# Processing row: ['jp,co,yahoo)/', '20000711004738', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'BV4ZKGE43UHLIUFFYLLGSA3BF6YUGW6R', '5509']
# Processing row: ['jp,co,yahoo)/', '20000711031359', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'BD3E6PT24SBPUUM3C3LJB2UTVXU33MLT', '5504']
# Processing row: ['jp,co,yahoo)/', '20000711032327', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'BD3E6PT24SBPUUM3C3LJB2UTVXU33MLT', '5505']
# Processing row: ['jp,co,yahoo)/', '20000711041514', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'BD3E6PT24SBPUUM3C3LJB2UTVXU33MLT', '5504']
# Processing row: ['jp,co,yahoo)/', '20000711063349', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'E4IPQ2CJ3R75ZQVT332JCUCRDNSYE3ZP', '5500']
# Processing row: ['jp,co,yahoo)/', '20000815053115', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'LUU4UHLUOUHE6NSSBYBLOABGBFRGBE63', '5611']
# Processing row: ['jp,co,yahoo)/', '20000816130258', 'http://www.yahoo.co.jp:80//', 'text/html', '200', '7U42CA2ELBNKYL627KU6U34YON3QULVX', '5724']
# Processing row: ['jp,co,yahoo)/', '20000919051938', 'http://www34.yahoo.co.jp:80/', 'text/html', '200', 'HGBH4R3GS4HPTUPGA52HUES35AOVCTUA', '8072']
# Processing row: ['jp,co,yahoo)/', '20001006214705', 'http://www112.yahoo.co.jp:80/', 'text/html', '200', 'XTQTUGJ3J5JBE2IG34LOQIZZU23REQ5K', '5405']
# Processing row: ['jp,co,yahoo)/', '20001008174854', 'http://www114.yahoo.co.jp:80/', 'text/html', '200', 'AGVMO5RM6TOXD76NIEERWFX2BVHWXUKM', '5355']
# Processing row: ['jp,co,yahoo)/', '20001017153402', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'NEEJPJDJREDYKJAZSWAQFWEAS4MKL6P7', '5522']
# Processing row: ['jp,co,yahoo)/', '20001017170508', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'NEEJPJDJREDYKJAZSWAQFWEAS4MKL6P7', '5521']
# Processing row: ['jp,co,yahoo)/', '20001017214932', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'KRAYVRB5A2WOV6AI3YVUQXHAKB5CZ5FE', '5522']
# Processing row: ['jp,co,yahoo)/', '20001018012624', 'http://www.yahoo.co.jp:80/?', 'text/plain', '302', 'VXEDWGPHSNERWHDOUD6YWRWNT4ZOLEX4', '120']
# Processing row: ['jp,co,yahoo)/', '20001018022111', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'PGXAII5CIMXJXARKW7TLPAIMRQERDACC', '5515']
# Processing row: ['jp,co,yahoo)/', '20001018022133', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'PGXAII5CIMXJXARKW7TLPAIMRQERDACC', '5518']
# Processing row: ['jp,co,yahoo)/', '20001018045026', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'KSTPZWNDAJCXKAMU3IRXZLP3URJABOR4', '5566']
# Processing row: ['jp,co,yahoo)/', '20001018070708', 'http://www34.yahoo.co.jp:80/', 'text/html', '200', 'ZOZ233HFPAGIASA2BG6NIMGUIEQYME6A', '6102']
# Processing row: ['jp,co,yahoo)/', '20001018075653', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'KSTPZWNDAJCXKAMU3IRXZLP3URJABOR4', '5566']
# Processing row: ['jp,co,yahoo)/', '20001018080308', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'KSTPZWNDAJCXKAMU3IRXZLP3URJABOR4', '5565']
# Processing row: ['jp,co,yahoo)/', '20001018114825', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 'DWJTSZQZTZ475BVATOXW4AC3JNIBN6ZZ', '5568']
# Processing row: ['jp,co,yahoo)/', '20001018122107', 'http://www110.yahoo.co.jp:80/', 'text/html', '200', '3F7GTNHDFERUP6QNR5BLMVXQVQNEH3Y7', '5508']
# Processing row: ['jp,co,yahoo)/', '20001018124426', 'http://www.yahoo.co.jp:80/', 'text/html', '200', 
 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'OI2UATG6YFIOPJK6CIFXILXPCND3ELMS', '8191']
# Processing row: ['jp,ne,biglobe)/', '20000229174034', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'WFMISFZQZL4MGVNLLVP5LHXHLWWGOHKU', '8123']
# Processing row: ['jp,ne,biglobe)/', '20000303180938', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'DBDBPJVJT3QGCAB5RBHO6WIJQVZ33J7X', '8181']
# Processing row: ['jp,ne,biglobe)/', '20000303212053', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'J4UHL2IIUT7BOJCIFJHJKYBZAFGWNFFE', '8153']
# Processing row: ['jp,ne,biglobe)/', '20000303221553', 'http://www2.biglobe.ne.jp:80/', 'text/html', '200', 'W2WFIWKNDAPUOUZCWN3VONUXYVCJA7ZN', '1567']
# Processing row: ['jp,ne,biglobe)/', '20000304193927', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'VOTABNHPHY7MAERZLW25FAO3YAZZQV5C', '8128']
# Processing row: ['jp,ne,biglobe)/', '20000510175943', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'IU5AG2DC5GK33ALX3VFXLUEAIHRTCDQF', '7672']
# Processing row: ['jp,ne,biglobe)/', '20000511080738', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'ZYKCBXXFANLESHZWMYCNPHOGXP3JUJBZ', '7718']
# Processing row: ['jp,ne,biglobe)/', '20000511120234', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'H7TGP2NL4MZRG7YQ22W7ZU4OILLSZPXA', '7628']
# Processing row: ['jp,ne,biglobe)/', '20000511142326', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'KMEPPAZXVGULOM7XF637RJASSMK2265X', '7653']
# Processing row: ['jp,ne,biglobe)/', '20000511154651', 'http://www2.biglobe.ne.jp:80/', 'text/html', '200', '4KNK22VDM4TY66WAHT2MAISY66L2MKHN', '1556']
# Processing row: ['jp,ne,biglobe)/', '20000511162331', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'WIXKMHR2E7OMYKNPMC2LOMXMMXXINAJP', '7674']
# Processing row: ['jp,ne,biglobe)/', '20000519231423', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'UIAW6DXDY276UBFWLIYPKU26QNSHIF4G', '7764']
# Processing row: ['jp,ne,biglobe)/', '20000613223027', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'RGFJROGHLXARWDLH2B7UZ6WLZAGQASPN', '7739']
# Processing row: ['jp,ne,biglobe)/', '20000619014435', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', '5IVA4TJ3HLHJDFWS2LRXRNLHDOSS6FYL', '7876']
# Processing row: ['jp,ne,biglobe)/', '20000619041018', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'UXVZUGB2PHS5WMZKGAQWWVJLUYJYGTGA', '7917']
# Processing row: ['jp,ne,biglobe)/', '20000619120532', 'http://www2.biglobe.ne.jp:80/', 'text/html', '200', '4KNK22VDM4TY66WAHT2MAISY66L2MKHN', '1557']
# Processing row: ['jp,ne,biglobe)/', '20000620112518', 'http://www2.biglobe.ne.jp:80/', 'text/html', '200', '4KNK22VDM4TY66WAHT2MAISY66L2MKHN', '1558']
# Processing row: ['jp,ne,biglobe)/', '20000621095002', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'KBTVQZOOLNIT2KEQ2EX544QQHW2AWZTK', '7939']
# Processing row: ['jp,ne,biglobe)/', '20000621202728', 'http://www2.biglobe.ne.jp:80/', 'text/html', '200', '4KNK22VDM4TY66WAHT2MAISY66L2MKHN', '1553']
# Processing row: ['jp,ne,biglobe)/', '20000706210811', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'V5HGBX4D2NCWB3NK6LRGT5YXMUN2MQHS', '7926']
# Processing row: ['jp,ne,biglobe)/', '20000711072750', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'IYCLSTE2C5AOQK7C76QUU6G2DDTZRURB', '7927']
# Processing row: ['jp,ne,biglobe)/', '20000815220000', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'ZYWBK6UQNPXV5TPOLVU6DXH5DZWBVF7H', '7908']
# Processing row: ['jp,ne,biglobe)/', '20000823205047', 'http://www2.biglobe.ne.jp:80/', 'text/html', '200', '6LFLAELEBZ5FJIAR4P4N6TZSRS7KBHQ5', '1552']
# Processing row: ['jp,ne,biglobe)/', '20000916203535', 'http://www2.biglobe.ne.jp:80/', 'text/html', '200', '4KNK22VDM4TY66WAHT2MAISY66L2MKHN', '1554']
# Processing row: ['jp,ne,biglobe)/', '20001012044605', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'WZMNBKNAVLDX64HPZI3A2RXOATALB4QM', '6716']
# Processing row: ['jp,ne,biglobe)/', '20001013150655', 'http://www2.biglobe.ne.jp:80/', 'text/html', '200', '6LFLAELEBZ5FJIAR4P4N6TZSRS7KBHQ5', '1560']
# Processing row: ['jp,ne,biglobe)/', '20001018100655', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'PWJA5THCXDVMUYN2KEAJNC3OGNVE3V2N', '6714']
# Processing row: ['jp,ne,biglobe)/', '20001018123944', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'ENE6HDKJEMQ6QUE24EDSTLLCR7PKJASI', '6823']
# Processing row: ['jp,ne,biglobe)/', '20001018124021', 'http://www.biglobe.ne.jp:80/?', 'text/html', '200', 'FTYZ6A7UMNCBYBVEPCNC6NPWZ5EFNUYF', '6755']
# Processing row: ['jp,ne,biglobe)/', '20001018145626', 'http://www2.biglobe.ne.jp:80/', 'text/html', '200', '4KNK22VDM4TY66WAHT2MAISY66L2MKHN', '1555']
# Processing row: ['jp,ne,biglobe)/', '20001018150025', 'http://www2.biglobe.ne.jp:80/', 'text/html', '200', '4KNK22VDM4TY66WAHT2MAISY66L2MKHN', '1555']
# Processing row: ['jp,ne,biglobe)/', '20001019032719', 'http://www.biglobe.ne.jp:80/?', 'text/html', '200', '37SIU457H3X2NJY6AEVSMTS6MWFMX66S', '6603']
# Processing row: ['jp,ne,biglobe)/', '20001019074956', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', '2ZZ3CNUZ4HYTQNFPBIOPLOZOQ2INI26A', '6731']
# Processing row: ['jp,ne,biglobe)/', '20001019092520', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'YQCE5IO4CZ2JUQHO3BNYOYRRGHRU2O76', '6633']
# Processing row: ['jp,ne,biglobe)/', '20001121102100', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'QHM3W27ZJFBA2GKDVNFOWPPXCW5M5YMW', '6632']
# Processing row: ['jp,ne,biglobe)/', '20001206081000', 'http://www.biglobe.ne.jp:80/', 'text/html', '200', 'J4RUWJ45QV7DZRJD6ZWTVKF3NSNRS6CS', '6654']
# Found 37 valid URLs in data/3/cdx.csv.
# Filtered down to 37 URLs that have not been downloaded yet.
# Downloaded http://www.biglobe.ne.jp:80/ at 20001019092520 to data/3/jp,ne,biglobe)/.html
# Downloaded http://www2.biglobe.ne.jp:80/ at 20000619120532 to data/3/jp,ne,biglobe)/.html
# Downloaded http://www.biglobe.ne.jp:80/ at 20000711072750 to data/3/jp,ne,biglobe)/.html
# Downloaded http://www2.biglobe.ne.jp:80/ at 20001018145626 to data/3/jp,ne,biglobe)/.html
# Downloaded http://www.biglobe.ne.jp:80/ at 20000519231423 to data/3/jp,ne,biglobe)/.html
# Downloaded http://www.biglobe.ne.jp:80/ at 20000229035555 to data/3/jp,ne,biglobe)/.html
# Downloaded http://www.biglobe.ne.jp:80/ at 20001012044605 to data/3/jp,ne,biglobe)/.html
# Downloaded http://www.biglobe.ne.jp:80/? at 20001018124021 to data/3/jp,ne,biglobe)/.html
# Downloaded http://www.biglobe.ne.jp:80/ at 20000511120234 to data/3/jp,ne,biglobe)/.html
# Downloaded http://www2.biglobe.ne.jp:80/ at 20000916203535 to data/3/jp,ne,biglobe)/.html
# Processing folder: data/4
# Processing row: ['jp,co,geocities)/', '20000226210411', 'http://www.geocities.co.jp:80/?', 'text/html', '200', '5U6DN34DP6KFFLX44PKF7H2XTLSCA7HT', '6373']
# Processing row: ['jp,co,geocities)/', '20000229102245', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'KTH47OYZH7MXPLRWQFMN7FBTZ46NT7MK', '6374']
# Processing row: ['jp,co,geocities)/', '20000229102245', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'KTH47OYZH7MXPLRWQFMN7FBTZ46NT7MK', '6374']
# Processing row: ['jp,co,geocities)/', '20000229212413', 'http://www02.geocities.co.jp:80/', 'text/html', '200', 'S6BTTDYZ55436DCOCVGEDU67L3AKNLHC', '5552']
# Processing row: ['jp,co,geocities)/', '20000229212413', 'http://www02.geocities.co.jp:80/', 'text/html', '200', 'S6BTTDYZ55436DCOCVGEDU67L3AKNLHC', '5552']
# Processing row: ['jp,co,geocities)/', '20000301052628', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'FQ3QFYVZEF726KB3K47HEQBH6QKT35WB', '5486']
# Processing row: ['jp,co,geocities)/', '20000301052628', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'FQ3QFYVZEF726KB3K47HEQBH6QKT35WB', '5486']
# Processing row: ['jp,co,geocities)/', '20000302211859', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'IUZUKY7AADDIHG4NON3QM2NZLXCQZ2TX', '5621']
# Processing row: ['jp,co,geocities)/', '20000302211859', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'IUZUKY7AADDIHG4NON3QM2NZLXCQZ2TX', '5621']
# Processing row: ['jp,co,geocities)/', '20000303154422', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'FQ3QFYVZEF726KB3K47HEQBH6QKT35WB', '5488']
# Processing row: ['jp,co,geocities)/', '20000304132031', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'FQ3QFYVZEF726KB3K47HEQBH6QKT35WB', '5485']
# Processing row: ['jp,co,geocities)/', '20000508202529', 'http://www.geocities.co.jp:80/', 'text/html', '200', '4XBO4XCTHQA6OEDRDKYNQTKZQN4HZNLR', '4948']
# Processing row: ['jp,co,geocities)/', '20000510051313', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UI3UF2DGZKHSYACPKCRTWJCEFHDOOVLR', '4886']
# Processing row: ['jp,co,geocities)/', '20000510114635', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'TAPNHNAQ47DRDSSRVUADHTF6MWDZXTQO', '4768']
# Processing row: ['jp,co,geocities)/', '20000510181225', 'http://www.geocities.co.jp:80/', 'text/html', '200', '3ECSDKZ3UDSODZYI44PJQP3USYL5PAKF', '4897']
# Processing row: ['jp,co,geocities)/', '20000511050932', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'TAPNHNAQ47DRDSSRVUADHTF6MWDZXTQO', '4770']
# Processing row: ['jp,co,geocities)/', '20000511163338', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'NCX4X56356QOV3AFA4BKQII3ND3JRWYA', '4897']
# Processing row: ['jp,co,geocities)/', '20000516010641', 'http://www.geocities.co.jp:80/', 'text/html', '200', 
 'http://www.geocities.co.jp:80/', 'text/html', '200', 'IIPPABWO363UZD3WRNXFC6ZD75HJWWMO', '5076']
# Processing row: ['jp,co,geocities)/', '20000729144335', 'http://www.geocities.co.jp:80/', 'text/html', '200', '5KIV45IP6HBFBHTDDTIFGVWFETSWCAXO', '5086']
# Processing row: ['jp,co,geocities)/', '20000729144335', 'http://www.geocities.co.jp:80/', 'text/html', '200', '5KIV45IP6HBFBHTDDTIFGVWFETSWCAXO', '5086']
# Processing row: ['jp,co,geocities)/', '20000729145344', 'http://www.geocities.co.jp:80/', 'text/html', '200', '7RK5QM5EEKKQQ6MCA3VEXWI2ENC3RW5D', '5223']
# Processing row: ['jp,co,geocities)/', '20000729145344', 'http://www.geocities.co.jp:80/', 'text/html', '200', '7RK5QM5EEKKQQ6MCA3VEXWI2ENC3RW5D', '5223']
# Processing row: ['jp,co,geocities)/', '20000729165413', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UEYL3BPX7K5TCJEL6MWBUNXRX3R4SRPS', '5170']
# Processing row: ['jp,co,geocities)/', '20000729165413', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UEYL3BPX7K5TCJEL6MWBUNXRX3R4SRPS', '5170']
# Processing row: ['jp,co,geocities)/', '20000729173404', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'RDOYEYIAEOKJ67PO6TUECEXHOPI3TYTT', '5077']
# Processing row: ['jp,co,geocities)/', '20000729173404', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'RDOYEYIAEOKJ67PO6TUECEXHOPI3TYTT', '5077']
# Processing row: ['jp,co,geocities)/', '20000729173811', 'http://www.geocities.co.jp:80/', 'text/html', '200', '5RBIQTFPR75W34DVUG65DNQKW5UIZTMS', '5185']
# Processing row: ['jp,co,geocities)/', '20000729173811', 'http://www.geocities.co.jp:80/', 'text/html', '200', '5RBIQTFPR75W34DVUG65DNQKW5UIZTMS', '5185']
# Processing row: ['jp,co,geocities)/', '20000729175725', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UEYL3BPX7K5TCJEL6MWBUNXRX3R4SRPS', '5169']
# Processing row: ['jp,co,geocities)/', '20000729175725', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UEYL3BPX7K5TCJEL6MWBUNXRX3R4SRPS', '5169']
# Processing row: ['jp,co,geocities)/', '20000729181637', 'http://www.geocities.co.jp:80/', 'text/html', '200', '5KIV45IP6HBFBHTDDTIFGVWFETSWCAXO', '5086']
# Processing row: ['jp,co,geocities)/', '20000729181637', 'http://www.geocities.co.jp:80/', 'text/html', '200', '5KIV45IP6HBFBHTDDTIFGVWFETSWCAXO', '5086']
# Processing row: ['jp,co,geocities)/', '20000729200053', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UEYL3BPX7K5TCJEL6MWBUNXRX3R4SRPS', '5167']
# Processing row: ['jp,co,geocities)/', '20000729200053', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UEYL3BPX7K5TCJEL6MWBUNXRX3R4SRPS', '5167']
# Processing row: ['jp,co,geocities)/', '20000729200616', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'V5YD3BSJMWYSSJCYFLUDQ4L4B6ITHR5T', '5169']
# Processing row: ['jp,co,geocities)/', '20000729200616', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'V5YD3BSJMWYSSJCYFLUDQ4L4B6ITHR5T', '5169']
# Processing row: ['jp,co,geocities)/', '20000729204059', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UEYL3BPX7K5TCJEL6MWBUNXRX3R4SRPS', '5167']
# Processing row: ['jp,co,geocities)/', '20000729204059', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UEYL3BPX7K5TCJEL6MWBUNXRX3R4SRPS', '5167']
# Processing row: ['jp,co,geocities)/', '20000804020547', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XHX6KRX5E35CTX76NFGZXRQ4LRN4JCJM', '5169']
# Processing row: ['jp,co,geocities)/', '20000804020547', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XHX6KRX5E35CTX76NFGZXRQ4LRN4JCJM', '5169']
# Processing row: ['jp,co,geocities)/', '20000804063042', 'http://www.geocities.co.jp:80/', 'text/html', '200', '
 'http://www.geocities.co.jp:80/', 'text/html', '200', 'L5Z6DR4ZDUFBMPMU4GV2O2D6H475S7QU', '5156']
# Processing row: ['jp,co,geocities)/', '20000804163922', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'L5Z6DR4ZDUFBMPMU4GV2O2D6H475S7QU', '5156']
# Processing row: ['jp,co,geocities)/', '20000804164759', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UYAB3UBZV3HP7TKNZ5CANAS7KLEH73HY', '5300']
# Processing row: ['jp,co,geocities)/', '20000804164759', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UYAB3UBZV3HP7TKNZ5CANAS7KLEH73HY', '5300']
# Processing row: ['jp,co,geocities)/', '20000804171744', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'Q3JBKSQNJO3WGWV2RJ7EPBHXGAWFZ4II', '5349']
# Processing row: ['jp,co,geocities)/', '20000804171744', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'Q3JBKSQNJO3WGWV2RJ7EPBHXGAWFZ4II', '5349']
# Processing row: ['jp,co,geocities)/', '20000804175534', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XHX6KRX5E35CTX76NFGZXRQ4LRN4JCJM', '5168']
# Processing row: ['jp,co,geocities)/', '20000804175534', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XHX6KRX5E35CTX76NFGZXRQ4LRN4JCJM', '5168']
# Processing row: ['jp,co,geocities)/', '20000804175838', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XHX6KRX5E35CTX76NFGZXRQ4LRN4JCJM', '5167']
# Processing row: ['jp,co,geocities)/', '20000804175838', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XHX6KRX5E35CTX76NFGZXRQ4LRN4JCJM', '5167']
# Processing row: ['jp,co,geocities)/', '20000804195818', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'EODYOVAEAMWHYF6GHLWHFM4AMA52YCU2', '5333']
# Processing row: ['jp,co,geocities)/', '20000804195818', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'EODYOVAEAMWHYF6GHLWHFM4AMA52YCU2', '5333']
# Processing row: ['jp,co,geocities)/', '20000804214055', 'http://www.geocities.co.jp:80/', 'text/html', '200', '4LI3EZ3Z56CQVQCLKXBZ7MSO5XPJNVCI', '5319']
# Processing row: ['jp,co,geocities)/', '20000804214055', 'http://www.geocities.co.jp:80/', 'text/html', '200', '4LI3EZ3Z56CQVQCLKXBZ7MSO5XPJNVCI', '5319']
# Processing row: ['jp,co,geocities)/', '20000804214055', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UJNXO6XOGGHBNCXQHSF655YVWT2IEUV4', '5266']
# Processing row: ['jp,co,geocities)/', '20000804214055', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'UJNXO6XOGGHBNCXQHSF655YVWT2IEUV4', '5266']
# Processing row: ['jp,co,geocities)/', '20000804214626', 'http://www.geocities.co.jp:80/', 'text/html', '200', '3AMURP6T4KBUS2ET3HGRDOH2IOH67K7Y', '5265']
# Processing row: ['jp,co,geocities)/', '20000804214626', 'http://www.geocities.co.jp:80/', 'text/html', '200', '3AMURP6T4KBUS2ET3HGRDOH2IOH67K7Y', '5265']
# Processing row: ['jp,co,geocities)/', '20000805002239', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'I6DOOWY7UF72IKAH77ZI5AJMS2EJPJHP', '5237']
# Processing row: ['jp,co,geocities)/', '20000805002239', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'I6DOOWY7UF72IKAH77ZI5AJMS2EJPJHP', '5237']
# Processing row: ['jp,co,geocities)/', '20000805050510', 'http://www.geocities.co.jp:80/', 'text/html', '200', '4LI3EZ3Z56CQVQCLKXBZ7MSO5XPJNVCI', '5318']
# Processing row: ['jp,co,geocities)/', '20000805050510', 'http://www.geocities.co.jp:80/', 'text/html', '200', '4LI3EZ3Z56CQVQCLKXBZ7MSO5XPJNVCI', '5318']
# Processing row: ['jp,co,geocities)/', '20000805051445', 'http://www.geocities.co.jp:80/', 'text/html', '200', '4JK25BZZOC6WEATGTMM5XQTW7WDXS3NN', '5259']
# Processing row: ['jp,co,geocities)/', '20000805051445', 'http://www.geocities.co.jp:80/', 'text/html', '200', '4JK25BZZOC6WEATGTMM5XQTW7WDXS3NN', '5259']
# Processing row: ['jp,co,geocities)/', '20000805090650', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'GSHFLKM6IW3PQU7KCPAWKTIR33OJN3VH', '5155']
# Processing row: ['jp,co,geocities)/', '20000805090650', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'GSHFLKM6IW3PQU7KCPAWKTIR33OJN3VH', '5155']
# Processing row: ['jp,co,geocities)/', '20000805095802', 'http://www.geocities.co.jp:80/', 'text/html', '200', '4LI3EZ3Z56CQVQCLKXBZ7MSO5XPJNVCI', '5318']
# Processing row: ['jp,co,geocities)/', '20000805095802', 'http://www.geocities.co.jp:80/', 'text/html', '200', '4LI3EZ3Z56CQVQCLKXBZ7MSO5XPJNVCI', '5318']
# Processing row: ['jp,co,geocities)/', '20000805103418', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XTM4QRWSU23E3ZN4YCGR7RWY2IPJLNT6', '5159']
# Processing row: ['jp,co,geocities)/', '20000805103418', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XTM4QRWSU23E3ZN4YCGR7RWY2IPJLNT6', '5159']
# Processing row: ['jp,co,geocities)/', '20000805110643', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XTM4QRWSU23E3ZN4YCGR7RWY2IPJLNT6', '5158']
# Processing row: ['jp,co,geocities)/', '20000805110643', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XTM4QRWSU23E3ZN4YCGR7RWY2IPJLNT6', '5158']
# Processing row: ['jp,co,geocities)/', '20000805123816', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'JACQQ7G32K72V6JOZUUYMWIRTRYOKNTT', '5263']
# Processing row: ['jp,co,geocities)/', '20000805123816', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'JACQQ7G32K72V6JOZUUYMWIRTRYOKNTT', '5263']
# Processing row: ['jp,co,geocities)/', '20000805125213', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XHX6KRX5E35CTX76NFGZXRQ4LRN4JCJM', '5167']
# Processing row: ['jp,co,geocities)/', '20000805125213', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XHX6KRX5E35CTX76NFGZXRQ4LRN4JCJM', '5167']
# Processing row: ['jp,co,geocities)/', '20000805125951', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'F4QLTCAS46GSB3SJX2V324YK4QRJJGYN', '5235']
# Processing row: ['jp,co,geocities)/', '20000805125951', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'F4QLTCAS46GSB3SJX2V324YK4QRJJGYN', '5235']
# Processing row: ['jp,co,geocities)/', '20000805135352', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XHX6KRX5E35CTX76NFGZXRQ4LRN4JCJM', '5167']
# Processing row: ['jp,co,geocities)/', '20000805135352', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XHX6KRX5E35CTX76NFGZXRQ4LRN4JCJM', '5167']
# Processing row: ['jp,co,geocities)/', '20000805135736', 'http://www.geocities.co.jp:80/', 'text/html', '200', 'XHX6KRX5E35CTX76NFGZXRQ4LRN4JCJM', '5167']
# ...
# Processing row: ['jp,or,plala)/', '20000907045149', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '357']
# Processing row: ['jp,or,plala)/', '20000909024619', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '357']
# Processing row: ['jp,or,plala)/', '20000909114446', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '357']
# Processing row: ['jp,or,plala)/', '20000909203811', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '358']
# Processing row: ['jp,or,plala)/', '20000916213626', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'DQOZOPCZYGFZKXSKUKAB6G2GBX7CLSBD', '359']
# Processing row: ['jp,or,plala)/', '20000916213626', 'http://www3.plala.or.jp:80/', 'text/html', '200', 'DQOZOPCZYGFZKXSKUKAB6G2GBX7CLSBD', '364']
# Processing row: ['jp,or,plala)/', '20000920212512', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '357']
# Processing row: ['jp,or,plala)/', '20000920231624', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '357']
# Processing row: ['jp,or,plala)/', '20000921021520', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '356']
# Processing row: ['jp,or,plala)/', '20000921081036', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '356']
# Processing row: ['jp,or,plala)/', '20000921104115', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '358']
# Processing row: ['jp,or,plala)/', '20000921105330', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '359']
# Processing row: ['jp,or,plala)/', '20000921161627', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '359']
# Processing row: ['jp,or,plala)/', '20000921172934', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '358']
# Processing row: ['jp,or,plala)/', '20000922035452', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '355']
# Processing row: ['jp,or,plala)/', '20000922071001', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '354']
# Processing row: ['jp,or,plala)/', '20000922074201', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '359']
# Processing row: ['jp,or,plala)/', '20000922084953', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '356']
# Processing row: ['jp,or,plala)/', '20000922085921', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '353']
# Processing row: ['jp,or,plala)/', '20000922131924', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '356']
# Processing row: ['jp,or,plala)/', '20000922181849', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '356']
# Processing row: ['jp,or,plala)/', '20000922225049', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '355']
# Processing row: ['jp,or,plala)/', '20000923020211', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '357']
# Processing row: ['jp,or,plala)/', '20000923022228', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '355']
# Processing row: ['jp,or,plala)/', '20000923024053', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '356']
# Processing row: ['jp,or,plala)/', '20000923051259', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '357']
# Processing row: ['jp,or,plala)/', '20000925175105', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '357']
# Processing row: ['jp,or,plala)/', '20000927060207', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '357']
# Processing row: ['jp,or,plala)/', '20000927230859', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '357']
# Processing row: ['jp,or,plala)/', '20000928135229', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '359']
# Processing row: ['jp,or,plala)/', '20000928170214', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '359']
# Processing row: ['jp,or,plala)/', '20000929000725', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '355']
# Processing row: ['jp,or,plala)/', '20000929060148', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '357']
# Processing row: ['jp,or,plala)/', '20000929074327', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '356']
# Processing row: ['jp,or,plala)/', '20000929204401', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '360']
# Processing row: ['jp,or,plala)/', '20000930001920', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '355']
# Processing row: ['jp,or,plala)/', '20001003131407', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '358']
# Processing row: ['jp,or,plala)/', '20001006065853', 'http://www.plala.or.jp:80/', 'text/html', '200', 'KJYVYNSHEYP67VDTBIJCGWBY52PQDRXD', '1199']
# Processing row: ['jp,or,plala)/', '20001009182941', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '357']
# Processing row: ['jp,or,plala)/', '20001009185802', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '360']
# Processing row: ['jp,or,plala)/', '20001009220116', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '361']
# Processing row: ['jp,or,plala)/', '20001010013947', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '355']
# Processing row: ['jp,or,plala)/', '20001010044342', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '355']
# Processing row: ['jp,or,plala)/', '20001010095220', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '356']
# Processing row: ['jp,or,plala)/', '20001010113258', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '354']
# Processing row: ['jp,or,plala)/', '20001010165146', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '356']
# Processing row: ['jp,or,plala)/', '20001011232642', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'NNDCWBO3ND7EZNEYBYSV32AGP6I2HOUN', '360']
# Processing row: ['jp,or,plala)/', '20001017120812', 'http://www.plala.or.jp:80/', 'text/html', '200', 'L6EWVQ45XZSCUFPGAAVAZOY625E3M755', '1203']
# Processing row: ['jp,or,plala)/', '20001018012815', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'DQOZOPCZYGFZKXSKUKAB6G2GBX7CLSBD', '361']
# Processing row: ['jp,or,plala)/', '20001018111639', 'http://www3.plala.or.jp:80/', 'text/html', '200', 'DQOZOPCZYGFZKXSKUKAB6G2GBX7CLSBD', '364']
# Processing row: ['jp,or,plala)/', '20001018125818', 'http://www.plala.or.jp:80/', 'text/html', '200', 'KJYVYNSHEYP67VDTBIJCGWBY52PQDRXD', '1204']
# Processing row: ['jp,or,plala)/', '20001018175108', 'http://www5.plala.or.jp:80/', 'text/html', '200', 'DQOZOPCZYGFZKXSKUKAB6G2GBX7CLSBD', '360']
# Processing row: ['jp,or,plala)/', '20001018180045', 'http://www3.plala.or.jp:80/', 'text/html', '200', 'DQOZOPCZYGFZKXSKUKAB6G2GBX7CLSBD', '365']
# Processing row: ['jp,or,plala)/', '20001018183024', 'http://www4.plala.or.jp:80/', 'text/html', '200', 'DQOZOPCZYGFZKXSKUKAB6G2GBX7CLSBD', '363']
# Processing row: ['jp,or,plala)/', '20001018233704', 'http://www2.plala.or.jp:80/', 'text/html', '200', 'DQOZOPCZYGFZKXSKUKAB6G2GBX7CLSBD', '359']
# Processing row: ['jp,or,plala)/', '20001019085812', 'http://www.plala.or.jp:80/', 'text/html', '200', 'KJYVYNSHEYP67VDTBIJCGWBY52PQDRXD', '1200']
# Processing row: ['jp,or,plala)/', '20001027202922', 'http://www1.plala.or.jp:80/', 'text/html', '200', 'DQOZOPCZYGFZKXSKUKAB6G2GBX7CLSBD', '361']
# Processing row: ['jp,or,plala)/', '20001110154300', 'http://www.plala.or.jp:80/', 'text/html', '200', 'KJYVYNSHEYP67VDTBIJCGWBY52PQDRXD', '1206']
# Processing row: ['jp,or,plala)/', '20001121035700', 'http://www3.plala.or.jp:80/', 'text/html', '200', 'DQOZOPCZYGFZKXSKUKAB6G2GBX7CLSBD', '362']
# Found 125 valid URLs in data/27/cdx.csv.
# Filtered down to 125 URLs that have not been downloaded yet.
# Error downloading http://www1.plala.or.jp:80/ at 20000922074201: Failed to download archive: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/20000922074201id_/http://www1.plala.or.jp:80/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f85c8335970>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error downloading http://www1.plala.or.jp:80/ at 20000805115047: Failed to download archive: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/20000805115047id_/http://www1.plala.or.jp:80/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f85c83368d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error downloading http://www2.plala.or.jp:80/ at 20000826220503: Failed to download archive: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/20000826220503id_/http://www2.plala.or.jp:80/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f85a5e9b710>: Failed to establish a new connection: [Errno 111] Connection refused'))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 33
#      31 timestamp = row[1]
#      32 try:
# ---> 33     html_content = retrieve_archive_html(url, timestamp)
#      34     # Save the HTML content to a file
#      35     html_file_path = folder / f"{row[0]}.html"
#
# Cell In[8], line 17, in retrieve_archive_html(original_url, timestamp)
#      14 wayback_url = f"https://web.archive.org/web/{timestamp}id_/{original_url}"
#      16 try:
# ---> 17     response = requests.get(wayback_url, timeout=10)
#      18     response.raise_for_status()
#      19     return response.text
#
# File ~/anaconda3/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.12/site-packages/requests/adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:615, in HTTPSConnection.connect(self)
#     613 def connect(self) -> None:
#     614     sock: socket.socket | ssl.SSLSocket
# --> 615     self.sock = sock = self._new_conn()
#     616     server_hostname: str = self.host
#     617     tls_in_tls = False
#
# File ~/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:196, in HTTPConnection._new_conn(self)
#     191 """Establish a socket connection and set nodelay settings on it.
#     192
#     193 :return: New socket connection.
#     194 """
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#     203     raise NameResolutionError(self.host, self, e) from e
#
# File ~/anaconda3/lib/python3.12/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:
