# %%
# This block shows how to use the Wayback Machine CDX API to get a list of available snapshots of a URL.
# It uses the requests library to make HTTP requests and the json library to parse the JSON response.
import requests
import json

# Function to get the CDX API URL for a given URL
def make_wm_cdx_url(url, from_time="19960101", to_time="20051231"):
    """
    Construct a URL to query the Wayback Machine CDX API
    for a given URL and time range
    """
    base_url = "https://web.archive.org/cdx/search/cdx"
    params = {
        "url": url,
        "from": from_time,
        "to": to_time,
    }

    # this will create a URL with the parameters
    # eg. https://web.archive.org/cdx/search/cdx?url=example.com&from=19960101&to=20051231
    url_with_params = requests.Request("GET", base_url, params=params).prepare().url
    return url_with_params

# %%
# download CDX data for all URLs in a CSV file. 
import csv
# load csv file nikkeibp-may2000-ja_only.csv 
def load_urls_from_csv(file_path):
    urls = []
    with open(file_path, 'r', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            if row:  # Check if the row is not empty
                urls.append(row)  # Assuming the URL is in the first column
    return urls


urls = load_urls_from_csv('nikkeibp-may2000-ja_only.csv')


import os

for url in urls:
    url_ranking = url[0]
    url = url[1]
    cdx_api_url = make_wm_cdx_url(url, from_time="20000101", to_time="20010101")
    print(f"Requesting CDX data for URL: {url_ranking} - {url}")
    # Make a request to the CDX API for the given URL, and save the response to a file named cdx.csv
    # stored in a subdirectory named after the URL ranking number

    # Check if there is already a cdx.csv file in the directory
    if os.path.exists(f"data/{url_ranking}/cdx.csv"):
        print(f"CDX data already exists for URL: {url_ranking} - {url}. Skipping download.")
        continue  # Skip to the next URL if the file already exists

    try:
        response = requests.get(cdx_api_url)
        response.raise_for_status()  # Raise an error for bad responses
        # Save the response content to a file named cdx.csv in a subdirectory named after the URL ranking number
        # Create the directory if it does not exist
        os.makedirs(f"data/{url_ranking}", exist_ok=True)
        # Write the response text to a file
        with open(f"data/{url_ranking}/cdx.csv", 'w', encoding='utf-8') as f:
            f.write(response.text)
        print(f"CDX data saved for URL: {url_ranking} - {url}")
    except requests.RequestException as e:
        print(f"Error fetching CDX data for URL: {url_ranking} - {url}. Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred for URL: {url_ranking} - {url}. Error: {e}")
# Out:
# Requesting CDX data for URL: 1 - yahoo.co.jp
# CDX data saved for URL: 1 - yahoo.co.jp
# Requesting CDX data for URL: 3 - biglobe.ne.jp
# CDX data saved for URL: 3 - biglobe.ne.jp
# Requesting CDX data for URL: 4 - geocities.co.jp
# CDX data saved for URL: 4 - geocities.co.jp
# Requesting CDX data for URL: 5 - nifty.com
# CDX data saved for URL: 5 - nifty.com
# Requesting CDX data for URL: 6 - nifty.ne.jp
# CDX data saved for URL: 6 - nifty.ne.jp
# Requesting CDX data for URL: 7 - dti.ne.jp
# CDX data saved for URL: 7 - dti.ne.jp
# Requesting CDX data for URL: 8 - so-net.ne.jp
# CDX data saved for URL: 8 - so-net.ne.jp
# Requesting CDX data for URL: 10 - hi-ho.ne.jp
# CDX data saved for URL: 10 - hi-ho.ne.jp
# Requesting CDX data for URL: 11 - infoweb.ne.jp
# CDX data saved for URL: 11 - infoweb.ne.jp
# Requesting CDX data for URL: 12 - mbn.or.jp
# CDX data saved for URL: 12 - mbn.or.jp
# Requesting CDX data for URL: 13 - lycos.co.jp
# CDX data saved for URL: 13 - lycos.co.jp
# Requesting CDX data for URL: 14 - goo.ne.jp
# CDX data saved for URL: 14 - goo.ne.jp
# Requesting CDX data for URL: 15 - odn.ne.jp
# CDX data saved for URL: 15 - odn.ne.jp
# Requesting CDX data for URL: 16 - asahi-net.or.jp
# CDX data saved for URL: 16 - asahi-net.or.jp
# Requesting CDX data for URL: 17 - justnet.ne.jp
# CDX data saved for URL: 17 - justnet.ne.jp
# Requesting CDX data for URL: 18 - rim.or.jp
# CDX data saved for URL: 18 - rim.or.jp
# Requesting CDX data for URL: 19 - interq.or.jp
# CDX data saved for URL: 19 - interq.or.jp
# Requesting CDX data for URL: 20 - iij4u.or.jp
# CDX data saved for URL: 20 - iij4u.or.jp
# Requesting CDX data for URL: 21 - neweb.ne.jp
# CDX data saved for URL: 21 - neweb.ne.jp
# Requesting CDX data for URL: 22 - infoseek.co.jp
# CDX data saved for URL: 22 - infoseek.co.jp
# Requesting CDX data for URL: 23 - bekkoame.ne.jp
# Error fetching CDX data for URL: 23 - bekkoame.ne.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=bekkoame.ne.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71a4b0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 24 - ocn.ne.jp
# Error fetching CDX data for URL: 24 - ocn.ne.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=ocn.ne.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71ac90>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 25 - rakuten.co.jp
# Error fetching CDX data for URL: 25 - rakuten.co.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=rakuten.co.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71b560>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 26 - dion.ne.jp
# Error fetching CDX data for URL: 26 - dion.ne.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=dion.ne.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71bef0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 27 - plala.or.jp
# Error fetching CDX data for URL: 27 - plala.or.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=plala.or.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d758830>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 28 - freeweb.ne.jp
# Error fetching CDX data for URL: 28 - freeweb.ne.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=freeweb.ne.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71bd10>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 29 - impress.co.jp
# Error fetching CDX data for URL: 29 - impress.co.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=impress.co.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71b200>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 30 - nikkeibp.co.jp
# Error fetching CDX data for URL: 30 - nikkeibp.co.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=nikkeibp.co.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71ab70>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 31 - sakura.ne.jp
# Error fetching CDX data for URL: 31 - sakura.ne.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=sakura.ne.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d7198b0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 32 - highway.ne.jp
# Error fetching CDX data for URL: 32 - highway.ne.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=highway.ne.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d758230>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 33 - tcup.com
# Error fetching CDX data for URL: 33 - tcup.com. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=tcup.com&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d759430>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 34 - msn.co.jp
# Error fetching CDX data for URL: 34 - msn.co.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=msn.co.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d718f20>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 35 - vector.co.jp
# Error fetching CDX data for URL: 35 - vector.co.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=vector.co.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d719e20>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 36 - tripod.co.jp
# Error fetching CDX data for URL: 36 - tripod.co.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=tripod.co.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71b320>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 37 - 3web.ne.jp
# Error fetching CDX data for URL: 37 - 3web.ne.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=3web.ne.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71bd70>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 38 - big.or.jp
# Error fetching CDX data for URL: 38 - big.or.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=big.or.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d758d40>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 39 - cplaza.ne.jp
# Error fetching CDX data for URL: 39 - cplaza.ne.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=cplaza.ne.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d758830>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 40 - iijnet.or.jp
# Error fetching CDX data for URL: 40 - iijnet.or.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=iijnet.or.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d75a030>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 41 - isize.com
# Error fetching CDX data for URL: 41 - isize.com. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=isize.com&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71b560>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 42 - excite.co.jp
# Error fetching CDX data for URL: 42 - excite.co.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=excite.co.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d718200>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 43 - cool.ne.jp
# Error fetching CDX data for URL: 43 - cool.ne.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=cool.ne.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71a2d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 44 - real.com
# Error fetching CDX data for URL: 44 - real.com. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=real.com&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d758470>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 45 - din.or.jp
# Error fetching CDX data for URL: 45 - din.or.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=din.or.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d758bc0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 47 - www.ne.jp
# Error fetching CDX data for URL: 47 - www.ne.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=www.ne.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d75a330>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 48 - xaxon.ne.jp
# Error fetching CDX data for URL: 48 - xaxon.ne.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=xaxon.ne.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71acf0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 49 - nikkei.co.jp
# Error fetching CDX data for URL: 49 - nikkei.co.jp. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=nikkei.co.jp&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71b1d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Requesting CDX data for URL: 50 - asahi.com
# Error fetching CDX data for URL: 50 - asahi.com. Error: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /cdx/search/cdx?url=asahi.com&from=20000101&to=20010101 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f484d71ad50>: Failed to establish a new connection: [Errno 111] Connection refused'))
